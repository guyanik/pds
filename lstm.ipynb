# %%
import numpy as np
import pandas as pd
from numpy import hstack
from numpy import concatenate
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras import optimizers
from keras.layers import Masking
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('daily.csv')
df['DATE'] = pd.to_datetime(df['DATE'])
df.dtypes
# Out:
# DATE            datetime64[ns]
# TEAMNAME                object
# USERCOUNT                int64
# SECONDSSPENT             int64
# QUANTITY                 int64
# VOLUME                 float64
# WEIGHT                 float64
# PRICE                  float64
# dtype: object

# %%
df = df[(df['DATE'] > '2022-08-10')]
# df = df[(df['DATE'] != '2020-07-22')]

# %%
df.columns
# Out:
# Index(['DATE', 'TEAMNAME', 'USERCOUNT', 'SECONDSSPENT', 'QUANTITY', 'VOLUME',
#        'WEIGHT', 'PRICE'],
#       dtype='object')

# %%
df = df[df['TEAMNAME'] != 'ID9']

df.index = pd.DatetimeIndex(df['DATE'])
df = df.drop(columns=['DATE'])
s = pd.DataFrame(index=pd.date_range(df.index.min(), df.index.max(), freq='D').difference(df.index), columns=df.columns)
df = pd.concat([df,s]).fillna(0).sort_index()
df['DATE'] = df.index
df = df.reset_index(drop=True)
df['TEAMNAME'] = df['TEAMNAME'].replace(0, 'DP1')

df_multi_index = pd.MultiIndex.from_product([df['DATE'].unique(), df['TEAMNAME'].unique()], names=['DATE', 'TEAMNAME'])
df = df.set_index(['DATE', 'TEAMNAME']).reindex(df_multi_index, fill_value=0).reset_index()
df

# write to csv
df.to_csv('try.csv')

# df_dp = df.loc[df['TEAMNAME'].isin(['DP1', 'DP2']), :]
# df_rest = df.loc[df['TEAMNAME'].isin(['DD', 'HD', 'HP1', 'HP2']), :].groupby('DATE').sum().reset_index()
# df_rest['TEAMNAME'] = 'REST'
# df = pd.concat([df_dp, df_rest])
# df = df.sort_values(by=['DATE', 'TEAMNAME'])

# %%
codes = dict(zip(df['TEAMNAME'].unique(), range(0, len(df['TEAMNAME'].unique()))))
codes
# Out:
# {'DP2': 0, 'DP1': 1, 'HP1': 2, 'HP2': 3, 'DD': 4, 'HD': 5}

# %%
# codes = {'DD': 0.001, 'DP2': 0.0004, 'DP1': 0.00035, 'HP1': 0.00005, 'HP2': 0.0001, 'HD': 0.0002}
# df['TEAMNAME'] = 1 / df['TEAMNAME'].map(codes)
# print(codes)
# df

# %%
date = df['DATE'].values.reshape(-1, 1)
seconds_spent = df['SECONDSSPENT'].values.reshape(-1, 1)
user_count = df['USERCOUNT'].values.reshape(-1, 1)
quantity = df['QUANTITY'].values.reshape(-1, 1)
volume = df['VOLUME'].values.reshape(-1, 1)
weight = df['WEIGHT'].values.reshape(-1, 1)
price = df['PRICE'].values.reshape(-1, 1)
team_name = df['TEAMNAME'].values.reshape(-1, 1)

# one hot encode TEAMNAME
onehot_encoder = OneHotEncoder(sparse_output=False)
team_name = onehot_encoder.fit_transform(df[['TEAMNAME']])
print(team_name.shape)
date = onehot_encoder.fit_transform(date)

scaler = MinMaxScaler(feature_range=(0, 1))
# seconds_spent = scaler.fit_transform(seconds_spent)
# user_count = scaler.fit_transform(user_count)
# quantity = scaler.fit_transform(quantity)
# volume = scaler.fit_transform(volume)
# weight = scaler.fit_transform(weight)
# price = scaler.fit_transform(price)

dataset = scaler.fit_transform(hstack((user_count, quantity, volume, weight, price, team_name, seconds_spent)))
# Out:
# (2460, 6)

# %%
# split into train and test sets
train_size = int(len(dataset) * 0.9)
test_size = len(dataset) - train_size

train, test = dataset[0:train_size, :], dataset[train_size:len(dataset), :]
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]

train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (2214, 1, 11) (2214,) (246, 1, 11) (246,)

# %%
# design network
np.random.seed(1234)
tf.random.set_seed(1234)

tf.keras.utils.set_random_seed(1234)
tf.config.experimental.enable_op_determinism()

optim = optimizers.Adam(lr=0.0001, decay=1e-6)

model = Sequential()
model.add(Masking(mask_value=0., input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(LSTM(10, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dropout(0.4))
model.add(Dense(1))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='mae', optimizer=optim)

# fit network
history = model.fit(train_X, train_y, epochs=300, batch_size=64, validation_data=(test_X, test_y), verbose=2, shuffle=False)

# plot history
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()
# Out:
# Epoch 1/300
# 2023-12-05 02:26:16.836448: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [2214]
# 	 [[{{node Placeholder/_11}}]]
# 2023-12-05 02:26:16.836712: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [2214]
# 	 [[{{node Placeholder/_11}}]]
# 2023-12-05 02:26:19.263851: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [246]
# 	 [[{{node Placeholder/_11}}]]
# 2023-12-05 02:26:19.264110: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [246]
# 	 [[{{node Placeholder/_11}}]]
# 35/35 - 3s - loss: 0.4089 - val_loss: 0.4239 - 3s/epoch - 91ms/step
# Epoch 2/300
# 35/35 - 0s - loss: 0.4076 - val_loss: 0.4224 - 75ms/epoch - 2ms/step
# Epoch 3/300
# 35/35 - 0s - loss: 0.4063 - val_loss: 0.4208 - 73ms/epoch - 2ms/step
# Epoch 4/300
# 35/35 - 0s - loss: 0.4049 - val_loss: 0.4192 - 69ms/epoch - 2ms/step
# Epoch 5/300
# 35/35 - 0s - loss: 0.4037 - val_loss: 0.4175 - 69ms/epoch - 2ms/step
# Epoch 6/300
# 35/35 - 0s - loss: 0.4024 - val_loss: 0.4158 - 69ms/epoch - 2ms/step
# Epoch 7/300
# 35/35 - 0s - loss: 0.4010 - val_loss: 0.4140 - 88ms/epoch - 3ms/step
# Epoch 8/300
# 35/35 - 0s - loss: 0.3995 - val_loss: 0.4122 - 69ms/epoch - 2ms/step
# Epoch 9/300
# 35/35 - 0s - loss: 0.3979 - val_loss: 0.4104 - 70ms/epoch - 2ms/step
# Epoch 10/300
# 35/35 - 0s - loss: 0.3964 - val_loss: 0.4084 - 72ms/epoch - 2ms/step
# Epoch 11/300
# 35/35 - 0s - loss: 0.3952 - val_loss: 0.4065 - 84ms/epoch - 2ms/step
# Epoch 12/300
# 35/35 - 0s - loss: 0.3932 - val_loss: 0.4044 - 73ms/epoch - 2ms/step
# Epoch 13/300
# 35/35 - 0s - loss: 0.3917 - val_loss: 0.4023 - 68ms/epoch - 2ms/step
# Epoch 14/300
# 35/35 - 0s - loss: 0.3900 - val_loss: 0.4001 - 69ms/epoch - 2ms/step
# Epoch 15/300
# 35/35 - 0s - loss: 0.3883 - val_loss: 0.3979 - 69ms/epoch - 2ms/step
# Epoch 16/300
# 35/35 - 0s - loss: 0.3864 - val_loss: 0.3956 - 69ms/epoch - 2ms/step
# Epoch 17/300
# 35/35 - 0s - loss: 0.3844 - val_loss: 0.3932 - 69ms/epoch - 2ms/step
# Epoch 18/300
# 35/35 - 0s - loss: 0.3826 - val_loss: 0.3907 - 68ms/epoch - 2ms/step
# Epoch 19/300
# 35/35 - 0s - loss: 0.3807 - val_loss: 0.3881 - 68ms/epoch - 2ms/step
# Epoch 20/300
# 35/35 - 0s - loss: 0.3787 - val_loss: 0.3855 - 68ms/epoch - 2ms/step
# Epoch 21/300
# 35/35 - 0s - loss: 0.3768 - val_loss: 0.3828 - 68ms/epoch - 2ms/step
# Epoch 22/300
# 35/35 - 0s - loss: 0.3749 - val_loss: 0.3801 - 69ms/epoch - 2ms/step
# Epoch 23/300
# 35/35 - 0s - loss: 0.3726 - val_loss: 0.3772 - 68ms/epoch - 2ms/step
# Epoch 24/300
# 35/35 - 0s - loss: 0.3700 - val_loss: 0.3742 - 68ms/epoch - 2ms/step
# Epoch 25/300
# 35/35 - 0s - loss: 0.3679 - val_loss: 0.3712 - 68ms/epoch - 2ms/step
# Epoch 26/300
# 35/35 - 0s - loss: 0.3652 - val_loss: 0.3681 - 68ms/epoch - 2ms/step
# Epoch 27/300
# 35/35 - 0s - loss: 0.3627 - val_loss: 0.3649 - 68ms/epoch - 2ms/step
# Epoch 28/300
# 35/35 - 0s - loss: 0.3600 - val_loss: 0.3615 - 68ms/epoch - 2ms/step
# Epoch 29/300
# 35/35 - 0s - loss: 0.3573 - val_loss: 0.3581 - 68ms/epoch - 2ms/step
# Epoch 30/300
# 35/35 - 0s - loss: 0.3550 - val_loss: 0.3546 - 67ms/epoch - 2ms/step
# Epoch 31/300
# 35/35 - 0s - loss: 0.3529 - val_loss: 0.3511 - 67ms/epoch - 2ms/step
# Epoch 32/300
# 35/35 - 0s - loss: 0.3494 - val_loss: 0.3475 - 67ms/epoch - 2ms/step
# Epoch 33/300
# 35/35 - 0s - loss: 0.3467 - val_loss: 0.3437 - 70ms/epoch - 2ms/step
# Epoch 34/300
# 35/35 - 0s - loss: 0.3441 - val_loss: 0.3399 - 68ms/epoch - 2ms/step
# Epoch 35/300
# 35/35 - 0s - loss: 0.3410 - val_loss: 0.3360 - 72ms/epoch - 2ms/step
# Epoch 36/300
# 35/35 - 0s - loss: 0.3378 - val_loss: 0.3321 - 70ms/epoch - 2ms/step
# Epoch 37/300
# 35/35 - 0s - loss: 0.3345 - val_loss: 0.3281 - 73ms/epoch - 2ms/step
# Epoch 38/300
# 35/35 - 0s - loss: 0.3316 - val_loss: 0.3239 - 72ms/epoch - 2ms/step
# Epoch 39/300
# 35/35 - 0s - loss: 0.3285 - val_loss: 0.3198 - 71ms/epoch - 2ms/step
# Epoch 40/300
# 35/35 - 0s - loss: 0.3254 - val_loss: 0.3155 - 68ms/epoch - 2ms/step
# Epoch 41/300
# 35/35 - 0s - loss: 0.3217 - val_loss: 0.3112 - 71ms/epoch - 2ms/step
# Epoch 42/300
# 35/35 - 0s - loss: 0.3179 - val_loss: 0.3068 - 72ms/epoch - 2ms/step
# Epoch 43/300
# 35/35 - 0s - loss: 0.3153 - val_loss: 0.3024 - 72ms/epoch - 2ms/step
# Epoch 44/300
# 35/35 - 0s - loss: 0.3117 - val_loss: 0.2979 - 70ms/epoch - 2ms/step
# Epoch 45/300
# 35/35 - 0s - loss: 0.3078 - val_loss: 0.2934 - 73ms/epoch - 2ms/step
# Epoch 46/300
# 35/35 - 0s - loss: 0.3042 - val_loss: 0.2889 - 73ms/epoch - 2ms/step
# Epoch 47/300
# 35/35 - 0s - loss: 0.3005 - val_loss: 0.2843 - 70ms/epoch - 2ms/step
# Epoch 48/300
# 35/35 - 0s - loss: 0.2968 - val_loss: 0.2797 - 71ms/epoch - 2ms/step
# Epoch 49/300
# 35/35 - 0s - loss: 0.2945 - val_loss: 0.2751 - 72ms/epoch - 2ms/step
# Epoch 50/300
# 35/35 - 0s - loss: 0.2893 - val_loss: 0.2705 - 70ms/epoch - 2ms/step
# Epoch 51/300
# 35/35 - 0s - loss: 0.2854 - val_loss: 0.2658 - 72ms/epoch - 2ms/step
# Epoch 52/300
# 35/35 - 0s - loss: 0.2820 - val_loss: 0.2612 - 69ms/epoch - 2ms/step
# Epoch 53/300
# 35/35 - 0s - loss: 0.2796 - val_loss: 0.2566 - 68ms/epoch - 2ms/step
# Epoch 54/300
# 35/35 - 0s - loss: 0.2755 - val_loss: 0.2521 - 67ms/epoch - 2ms/step
# Epoch 55/300
# 35/35 - 0s - loss: 0.2709 - val_loss: 0.2475 - 69ms/epoch - 2ms/step
# Epoch 56/300
# 35/35 - 0s - loss: 0.2676 - val_loss: 0.2430 - 68ms/epoch - 2ms/step
# Epoch 57/300
# 35/35 - 0s - loss: 0.2635 - val_loss: 0.2385 - 67ms/epoch - 2ms/step
# Epoch 58/300
# 35/35 - 0s - loss: 0.2605 - val_loss: 0.2341 - 69ms/epoch - 2ms/step
# Epoch 59/300
# 35/35 - 0s - loss: 0.2567 - val_loss: 0.2297 - 94ms/epoch - 3ms/step
# Epoch 60/300
# 35/35 - 0s - loss: 0.2533 - val_loss: 0.2255 - 69ms/epoch - 2ms/step
# Epoch 61/300
# 35/35 - 0s - loss: 0.2495 - val_loss: 0.2212 - 67ms/epoch - 2ms/step
# Epoch 62/300
# 35/35 - 0s - loss: 0.2448 - val_loss: 0.2170 - 68ms/epoch - 2ms/step
# Epoch 63/300
# 35/35 - 0s - loss: 0.2419 - val_loss: 0.2128 - 68ms/epoch - 2ms/step
# Epoch 64/300
# 35/35 - 0s - loss: 0.2394 - val_loss: 0.2086 - 68ms/epoch - 2ms/step
# Epoch 65/300
# 35/35 - 0s - loss: 0.2360 - val_loss: 0.2045 - 68ms/epoch - 2ms/step
# Epoch 66/300
# 35/35 - 0s - loss: 0.2327 - val_loss: 0.2005 - 67ms/epoch - 2ms/step
# Epoch 67/300
# 35/35 - 0s - loss: 0.2303 - val_loss: 0.1966 - 68ms/epoch - 2ms/step
# Epoch 68/300
# 35/35 - 0s - loss: 0.2258 - val_loss: 0.1927 - 68ms/epoch - 2ms/step
# Epoch 69/300
# 35/35 - 0s - loss: 0.2219 - val_loss: 0.1888 - 67ms/epoch - 2ms/step
# Epoch 70/300
# 35/35 - 0s - loss: 0.2170 - val_loss: 0.1851 - 67ms/epoch - 2ms/step
# Epoch 71/300
# 35/35 - 0s - loss: 0.2159 - val_loss: 0.1814 - 68ms/epoch - 2ms/step
# Epoch 72/300
# 35/35 - 0s - loss: 0.2128 - val_loss: 0.1777 - 68ms/epoch - 2ms/step
# Epoch 73/300
# 35/35 - 0s - loss: 0.2095 - val_loss: 0.1741 - 67ms/epoch - 2ms/step
# Epoch 74/300
# 35/35 - 0s - loss: 0.2063 - val_loss: 0.1705 - 67ms/epoch - 2ms/step
# Epoch 75/300
# 35/35 - 0s - loss: 0.2026 - val_loss: 0.1670 - 68ms/epoch - 2ms/step
# Epoch 76/300
# 35/35 - 0s - loss: 0.1985 - val_loss: 0.1635 - 67ms/epoch - 2ms/step
# Epoch 77/300
# 35/35 - 0s - loss: 0.1968 - val_loss: 0.1602 - 67ms/epoch - 2ms/step
# Epoch 78/300
# 35/35 - 0s - loss: 0.1943 - val_loss: 0.1569 - 68ms/epoch - 2ms/step
# Epoch 79/300
# 35/35 - 0s - loss: 0.1911 - val_loss: 0.1537 - 67ms/epoch - 2ms/step
# Epoch 80/300
# 35/35 - 0s - loss: 0.1869 - val_loss: 0.1505 - 68ms/epoch - 2ms/step
# Epoch 81/300
# 35/35 - 0s - loss: 0.1856 - val_loss: 0.1474 - 68ms/epoch - 2ms/step
# Epoch 82/300
# 35/35 - 0s - loss: 0.1835 - val_loss: 0.1444 - 68ms/epoch - 2ms/step
# Epoch 83/300
# 35/35 - 0s - loss: 0.1799 - val_loss: 0.1414 - 67ms/epoch - 2ms/step
# Epoch 84/300
# 35/35 - 0s - loss: 0.1782 - val_loss: 0.1386 - 68ms/epoch - 2ms/step
# Epoch 85/300
# 35/35 - 0s - loss: 0.1746 - val_loss: 0.1358 - 68ms/epoch - 2ms/step
# Epoch 86/300
# 35/35 - 0s - loss: 0.1720 - val_loss: 0.1330 - 67ms/epoch - 2ms/step
# Epoch 87/300
# 35/35 - 0s - loss: 0.1702 - val_loss: 0.1303 - 68ms/epoch - 2ms/step
# Epoch 88/300
# 35/35 - 0s - loss: 0.1662 - val_loss: 0.1277 - 66ms/epoch - 2ms/step
# Epoch 89/300
# 35/35 - 0s - loss: 0.1650 - val_loss: 0.1252 - 68ms/epoch - 2ms/step
# Epoch 90/300
# 35/35 - 0s - loss: 0.1627 - val_loss: 0.1227 - 69ms/epoch - 2ms/step
# Epoch 91/300
# 35/35 - 0s - loss: 0.1629 - val_loss: 0.1203 - 68ms/epoch - 2ms/step
# Epoch 92/300
# 35/35 - 0s - loss: 0.1589 - val_loss: 0.1179 - 67ms/epoch - 2ms/step
# Epoch 93/300
# 35/35 - 0s - loss: 0.1551 - val_loss: 0.1156 - 68ms/epoch - 2ms/step
# Epoch 94/300
# 35/35 - 0s - loss: 0.1552 - val_loss: 0.1134 - 68ms/epoch - 2ms/step
# Epoch 95/300
# 35/35 - 0s - loss: 0.1522 - val_loss: 0.1112 - 67ms/epoch - 2ms/step
# Epoch 96/300
# 35/35 - 0s - loss: 0.1507 - val_loss: 0.1090 - 69ms/epoch - 2ms/step
# Epoch 97/300
# 35/35 - 0s - loss: 0.1478 - val_loss: 0.1069 - 69ms/epoch - 2ms/step
# Epoch 98/300
# 35/35 - 0s - loss: 0.1462 - val_loss: 0.1048 - 67ms/epoch - 2ms/step
# Epoch 99/300
# 35/35 - 0s - loss: 0.1425 - val_loss: 0.1028 - 68ms/epoch - 2ms/step
# Epoch 100/300
# 35/35 - 0s - loss: 0.1411 - val_loss: 0.1008 - 68ms/epoch - 2ms/step
# Epoch 101/300
# 35/35 - 0s - loss: 0.1403 - val_loss: 0.0989 - 67ms/epoch - 2ms/step
# Epoch 102/300
# 35/35 - 0s - loss: 0.1387 - val_loss: 0.0970 - 68ms/epoch - 2ms/step
# Epoch 103/300
# 35/35 - 0s - loss: 0.1365 - val_loss: 0.0952 - 68ms/epoch - 2ms/step
# Epoch 104/300
# 35/35 - 0s - loss: 0.1345 - val_loss: 0.0934 - 68ms/epoch - 2ms/step
# Epoch 105/300
# 35/35 - 0s - loss: 0.1342 - val_loss: 0.0916 - 67ms/epoch - 2ms/step
# Epoch 106/300
# 35/35 - 0s - loss: 0.1308 - val_loss: 0.0898 - 68ms/epoch - 2ms/step
# Epoch 107/300
# 35/35 - 0s - loss: 0.1295 - val_loss: 0.0881 - 66ms/epoch - 2ms/step
# Epoch 108/300
# 35/35 - 0s - loss: 0.1266 - val_loss: 0.0865 - 67ms/epoch - 2ms/step
# Epoch 109/300
# 35/35 - 0s - loss: 0.1237 - val_loss: 0.0849 - 68ms/epoch - 2ms/step
# Epoch 110/300
# 35/35 - 0s - loss: 0.1230 - val_loss: 0.0833 - 68ms/epoch - 2ms/step
# Epoch 111/300
# 35/35 - 0s - loss: 0.1227 - val_loss: 0.0817 - 68ms/epoch - 2ms/step
# Epoch 112/300
# 35/35 - 0s - loss: 0.1206 - val_loss: 0.0802 - 69ms/epoch - 2ms/step
# Epoch 113/300
# 35/35 - 0s - loss: 0.1162 - val_loss: 0.0787 - 67ms/epoch - 2ms/step
# Epoch 114/300
# 35/35 - 0s - loss: 0.1149 - val_loss: 0.0772 - 68ms/epoch - 2ms/step
# Epoch 115/300
# 35/35 - 0s - loss: 0.1152 - val_loss: 0.0758 - 68ms/epoch - 2ms/step
# Epoch 116/300
# 35/35 - 0s - loss: 0.1125 - val_loss: 0.0744 - 66ms/epoch - 2ms/step
# Epoch 117/300
# 35/35 - 0s - loss: 0.1116 - val_loss: 0.0731 - 68ms/epoch - 2ms/step
# Epoch 118/300
# 35/35 - 0s - loss: 0.1091 - val_loss: 0.0718 - 68ms/epoch - 2ms/step
# Epoch 119/300
# 35/35 - 0s - loss: 0.1081 - val_loss: 0.0705 - 68ms/epoch - 2ms/step
# Epoch 120/300
# 35/35 - 0s - loss: 0.1082 - val_loss: 0.0691 - 68ms/epoch - 2ms/step
# Epoch 121/300
# 35/35 - 0s - loss: 0.1065 - val_loss: 0.0679 - 68ms/epoch - 2ms/step
# Epoch 122/300
# 35/35 - 0s - loss: 0.1045 - val_loss: 0.0667 - 67ms/epoch - 2ms/step
# Epoch 123/300
# 35/35 - 0s - loss: 0.1018 - val_loss: 0.0655 - 68ms/epoch - 2ms/step
# Epoch 124/300
# 35/35 - 0s - loss: 0.0992 - val_loss: 0.0644 - 67ms/epoch - 2ms/step
# Epoch 125/300
# 35/35 - 0s - loss: 0.0980 - val_loss: 0.0634 - 67ms/epoch - 2ms/step
# Epoch 126/300
# 35/35 - 0s - loss: 0.0965 - val_loss: 0.0623 - 68ms/epoch - 2ms/step
# Epoch 127/300
# 35/35 - 0s - loss: 0.0947 - val_loss: 0.0613 - 68ms/epoch - 2ms/step
# Epoch 128/300
# 35/35 - 0s - loss: 0.0947 - val_loss: 0.0603 - 67ms/epoch - 2ms/step
# Epoch 129/300
# 35/35 - 0s - loss: 0.0948 - val_loss: 0.0593 - 68ms/epoch - 2ms/step
# Epoch 130/300
# 35/35 - 0s - loss: 0.0921 - val_loss: 0.0584 - 67ms/epoch - 2ms/step
# Epoch 131/300
# 35/35 - 0s - loss: 0.0876 - val_loss: 0.0575 - 66ms/epoch - 2ms/step
# Epoch 132/300
# 35/35 - 0s - loss: 0.0877 - val_loss: 0.0567 - 68ms/epoch - 2ms/step
# Epoch 133/300
# 35/35 - 0s - loss: 0.0888 - val_loss: 0.0558 - 104ms/epoch - 3ms/step
# Epoch 134/300
# 35/35 - 0s - loss: 0.0852 - val_loss: 0.0550 - 68ms/epoch - 2ms/step
# Epoch 135/300
# 35/35 - 0s - loss: 0.0834 - val_loss: 0.0542 - 68ms/epoch - 2ms/step
# Epoch 136/300
# 35/35 - 0s - loss: 0.0844 - val_loss: 0.0536 - 68ms/epoch - 2ms/step
# Epoch 137/300
# 35/35 - 0s - loss: 0.0816 - val_loss: 0.0530 - 109ms/epoch - 3ms/step
# Epoch 138/300
# 35/35 - 0s - loss: 0.0791 - val_loss: 0.0523 - 69ms/epoch - 2ms/step
# Epoch 139/300
# 35/35 - 0s - loss: 0.0789 - val_loss: 0.0517 - 68ms/epoch - 2ms/step
# Epoch 140/300
# 35/35 - 0s - loss: 0.0793 - val_loss: 0.0511 - 68ms/epoch - 2ms/step
# Epoch 141/300
# 35/35 - 0s - loss: 0.0762 - val_loss: 0.0505 - 71ms/epoch - 2ms/step
# Epoch 142/300
# 35/35 - 0s - loss: 0.0768 - val_loss: 0.0499 - 69ms/epoch - 2ms/step
# Epoch 143/300
# 35/35 - 0s - loss: 0.0746 - val_loss: 0.0493 - 67ms/epoch - 2ms/step
# Epoch 144/300
# 35/35 - 0s - loss: 0.0736 - val_loss: 0.0488 - 68ms/epoch - 2ms/step
# Epoch 145/300
# 35/35 - 0s - loss: 0.0730 - val_loss: 0.0482 - 67ms/epoch - 2ms/step
# Epoch 146/300
# 35/35 - 0s - loss: 0.0726 - val_loss: 0.0477 - 66ms/epoch - 2ms/step
# Epoch 147/300
# 35/35 - 0s - loss: 0.0701 - val_loss: 0.0471 - 69ms/epoch - 2ms/step
# Epoch 148/300
# 35/35 - 0s - loss: 0.0695 - val_loss: 0.0466 - 67ms/epoch - 2ms/step
# Epoch 149/300
# 35/35 - 0s - loss: 0.0684 - val_loss: 0.0462 - 67ms/epoch - 2ms/step
# Epoch 150/300
# 35/35 - 0s - loss: 0.0672 - val_loss: 0.0457 - 68ms/epoch - 2ms/step
# Epoch 151/300
# 35/35 - 0s - loss: 0.0650 - val_loss: 0.0453 - 68ms/epoch - 2ms/step
# Epoch 152/300
# 35/35 - 0s - loss: 0.0655 - val_loss: 0.0447 - 67ms/epoch - 2ms/step
# Epoch 153/300
# 35/35 - 0s - loss: 0.0636 - val_loss: 0.0442 - 67ms/epoch - 2ms/step
# Epoch 154/300
# 35/35 - 0s - loss: 0.0634 - val_loss: 0.0437 - 69ms/epoch - 2ms/step
# Epoch 155/300
# 35/35 - 0s - loss: 0.0644 - val_loss: 0.0434 - 67ms/epoch - 2ms/step
# Epoch 156/300
# 35/35 - 0s - loss: 0.0618 - val_loss: 0.0429 - 69ms/epoch - 2ms/step
# Epoch 157/300
# 35/35 - 0s - loss: 0.0617 - val_loss: 0.0424 - 68ms/epoch - 2ms/step
# Epoch 158/300
# 35/35 - 0s - loss: 0.0599 - val_loss: 0.0419 - 67ms/epoch - 2ms/step
# Epoch 159/300
# 35/35 - 0s - loss: 0.0603 - val_loss: 0.0414 - 67ms/epoch - 2ms/step
# Epoch 160/300
# 35/35 - 0s - loss: 0.0598 - val_loss: 0.0409 - 67ms/epoch - 2ms/step
# Epoch 161/300
# 35/35 - 0s - loss: 0.0584 - val_loss: 0.0403 - 67ms/epoch - 2ms/step
# Epoch 162/300
# 35/35 - 0s - loss: 0.0584 - val_loss: 0.0398 - 67ms/epoch - 2ms/step
# Epoch 163/300
# 35/35 - 0s - loss: 0.0575 - val_loss: 0.0394 - 69ms/epoch - 2ms/step
# Epoch 164/300
# 35/35 - 0s - loss: 0.0576 - val_loss: 0.0389 - 67ms/epoch - 2ms/step
# Epoch 165/300
# 35/35 - 0s - loss: 0.0548 - val_loss: 0.0384 - 67ms/epoch - 2ms/step
# Epoch 166/300
# 35/35 - 0s - loss: 0.0552 - val_loss: 0.0380 - 71ms/epoch - 2ms/step
# Epoch 167/300
# 35/35 - 0s - loss: 0.0538 - val_loss: 0.0375 - 68ms/epoch - 2ms/step
# Epoch 168/300
# 35/35 - 0s - loss: 0.0544 - val_loss: 0.0372 - 68ms/epoch - 2ms/step
# Epoch 169/300
# 35/35 - 0s - loss: 0.0549 - val_loss: 0.0367 - 68ms/epoch - 2ms/step
# Epoch 170/300
# 35/35 - 0s - loss: 0.0532 - val_loss: 0.0362 - 67ms/epoch - 2ms/step
# Epoch 171/300
# 35/35 - 0s - loss: 0.0520 - val_loss: 0.0356 - 67ms/epoch - 2ms/step
# Epoch 172/300
# 35/35 - 0s - loss: 0.0526 - val_loss: 0.0353 - 67ms/epoch - 2ms/step
# Epoch 173/300
# 35/35 - 0s - loss: 0.0517 - val_loss: 0.0350 - 67ms/epoch - 2ms/step
# Epoch 174/300
# 35/35 - 0s - loss: 0.0503 - val_loss: 0.0345 - 67ms/epoch - 2ms/step
# Epoch 175/300
# 35/35 - 0s - loss: 0.0507 - val_loss: 0.0343 - 67ms/epoch - 2ms/step
# Epoch 176/300
# 35/35 - 0s - loss: 0.0511 - val_loss: 0.0341 - 69ms/epoch - 2ms/step
# Epoch 177/300
# 35/35 - 0s - loss: 0.0495 - val_loss: 0.0336 - 67ms/epoch - 2ms/step
# Epoch 178/300
# 35/35 - 0s - loss: 0.0488 - val_loss: 0.0331 - 67ms/epoch - 2ms/step
# Epoch 179/300
# 35/35 - 0s - loss: 0.0490 - val_loss: 0.0327 - 68ms/epoch - 2ms/step
# Epoch 180/300
# 35/35 - 0s - loss: 0.0491 - val_loss: 0.0325 - 67ms/epoch - 2ms/step
# Epoch 181/300
# 35/35 - 0s - loss: 0.0485 - val_loss: 0.0322 - 67ms/epoch - 2ms/step
# Epoch 182/300
# 35/35 - 0s - loss: 0.0480 - val_loss: 0.0319 - 67ms/epoch - 2ms/step
# Epoch 183/300
# 35/35 - 0s - loss: 0.0456 - val_loss: 0.0315 - 68ms/epoch - 2ms/step
# Epoch 184/300
# 35/35 - 0s - loss: 0.0473 - val_loss: 0.0312 - 68ms/epoch - 2ms/step
# Epoch 185/300
# 35/35 - 0s - loss: 0.0468 - val_loss: 0.0309 - 68ms/epoch - 2ms/step
# Epoch 186/300
# 35/35 - 0s - loss: 0.0468 - val_loss: 0.0308 - 66ms/epoch - 2ms/step
# Epoch 187/300
# 35/35 - 0s - loss: 0.0446 - val_loss: 0.0306 - 67ms/epoch - 2ms/step
# Epoch 188/300
# 35/35 - 0s - loss: 0.0454 - val_loss: 0.0303 - 69ms/epoch - 2ms/step
# Epoch 189/300
# 35/35 - 0s - loss: 0.0463 - val_loss: 0.0301 - 67ms/epoch - 2ms/step
# Epoch 190/300
# 35/35 - 0s - loss: 0.0451 - val_loss: 0.0298 - 67ms/epoch - 2ms/step
# Epoch 191/300
# 35/35 - 0s - loss: 0.0448 - val_loss: 0.0298 - 68ms/epoch - 2ms/step
# Epoch 192/300
# 35/35 - 0s - loss: 0.0434 - val_loss: 0.0294 - 69ms/epoch - 2ms/step
# Epoch 193/300
# 35/35 - 0s - loss: 0.0427 - val_loss: 0.0290 - 67ms/epoch - 2ms/step
# Epoch 194/300
# 35/35 - 0s - loss: 0.0442 - val_loss: 0.0289 - 68ms/epoch - 2ms/step
# Epoch 195/300
# 35/35 - 0s - loss: 0.0443 - val_loss: 0.0287 - 137ms/epoch - 4ms/step
# Epoch 196/300
# 35/35 - 0s - loss: 0.0423 - val_loss: 0.0285 - 72ms/epoch - 2ms/step
# Epoch 197/300
# 35/35 - 0s - loss: 0.0444 - val_loss: 0.0284 - 67ms/epoch - 2ms/step
# Epoch 198/300
# 35/35 - 0s - loss: 0.0435 - val_loss: 0.0281 - 67ms/epoch - 2ms/step
# Epoch 199/300
# 35/35 - 0s - loss: 0.0423 - val_loss: 0.0280 - 68ms/epoch - 2ms/step
# Epoch 200/300
# 35/35 - 0s - loss: 0.0425 - val_loss: 0.0277 - 67ms/epoch - 2ms/step
# Epoch 201/300
# 35/35 - 0s - loss: 0.0415 - val_loss: 0.0277 - 68ms/epoch - 2ms/step
# Epoch 202/300
# 35/35 - 0s - loss: 0.0424 - val_loss: 0.0277 - 67ms/epoch - 2ms/step
# Epoch 203/300
# 35/35 - 0s - loss: 0.0423 - val_loss: 0.0273 - 68ms/epoch - 2ms/step
# Epoch 204/300
# 35/35 - 0s - loss: 0.0422 - val_loss: 0.0273 - 131ms/epoch - 4ms/step
# Epoch 205/300
# 35/35 - 0s - loss: 0.0413 - val_loss: 0.0273 - 78ms/epoch - 2ms/step
# Epoch 206/300
# 35/35 - 0s - loss: 0.0407 - val_loss: 0.0272 - 68ms/epoch - 2ms/step
# Epoch 207/300
# 35/35 - 0s - loss: 0.0410 - val_loss: 0.0269 - 68ms/epoch - 2ms/step
# Epoch 208/300
# 35/35 - 0s - loss: 0.0398 - val_loss: 0.0266 - 67ms/epoch - 2ms/step
# Epoch 209/300
# 35/35 - 0s - loss: 0.0406 - val_loss: 0.0266 - 67ms/epoch - 2ms/step
# Epoch 210/300
# 35/35 - 0s - loss: 0.0407 - val_loss: 0.0263 - 95ms/epoch - 3ms/step
# Epoch 211/300
# 35/35 - 0s - loss: 0.0391 - val_loss: 0.0262 - 69ms/epoch - 2ms/step
# Epoch 212/300
# 35/35 - 0s - loss: 0.0386 - val_loss: 0.0262 - 67ms/epoch - 2ms/step
# Epoch 213/300
# 35/35 - 0s - loss: 0.0399 - val_loss: 0.0261 - 67ms/epoch - 2ms/step
# Epoch 214/300
# 35/35 - 0s - loss: 0.0390 - val_loss: 0.0256 - 68ms/epoch - 2ms/step
# Epoch 215/300
# 35/35 - 0s - loss: 0.0384 - val_loss: 0.0254 - 66ms/epoch - 2ms/step
# Epoch 216/300
# 35/35 - 0s - loss: 0.0391 - val_loss: 0.0254 - 67ms/epoch - 2ms/step
# Epoch 217/300
# 35/35 - 0s - loss: 0.0375 - val_loss: 0.0252 - 68ms/epoch - 2ms/step
# Epoch 218/300
# 35/35 - 0s - loss: 0.0371 - val_loss: 0.0250 - 68ms/epoch - 2ms/step
# Epoch 219/300
# 35/35 - 0s - loss: 0.0380 - val_loss: 0.0248 - 93ms/epoch - 3ms/step
# Epoch 220/300
# 35/35 - 0s - loss: 0.0381 - val_loss: 0.0247 - 67ms/epoch - 2ms/step
# Epoch 221/300
# 35/35 - 0s - loss: 0.0387 - val_loss: 0.0249 - 68ms/epoch - 2ms/step
# Epoch 222/300
# 35/35 - 0s - loss: 0.0371 - val_loss: 0.0249 - 67ms/epoch - 2ms/step
# Epoch 223/300
# 35/35 - 0s - loss: 0.0383 - val_loss: 0.0249 - 67ms/epoch - 2ms/step
# Epoch 224/300
# 35/35 - 0s - loss: 0.0376 - val_loss: 0.0249 - 68ms/epoch - 2ms/step
# Epoch 225/300
# 35/35 - 0s - loss: 0.0370 - val_loss: 0.0247 - 68ms/epoch - 2ms/step
# Epoch 226/300
# 35/35 - 0s - loss: 0.0371 - val_loss: 0.0245 - 68ms/epoch - 2ms/step
# Epoch 227/300
# 35/35 - 0s - loss: 0.0374 - val_loss: 0.0242 - 69ms/epoch - 2ms/step
# Epoch 228/300
# 35/35 - 0s - loss: 0.0372 - val_loss: 0.0242 - 93ms/epoch - 3ms/step
# Epoch 229/300
# 35/35 - 0s - loss: 0.0371 - val_loss: 0.0240 - 67ms/epoch - 2ms/step
# Epoch 230/300
# 35/35 - 0s - loss: 0.0372 - val_loss: 0.0240 - 68ms/epoch - 2ms/step
# Epoch 231/300
# 35/35 - 0s - loss: 0.0370 - val_loss: 0.0238 - 68ms/epoch - 2ms/step
# Epoch 232/300
# 35/35 - 0s - loss: 0.0372 - val_loss: 0.0238 - 67ms/epoch - 2ms/step
# Epoch 233/300
# 35/35 - 0s - loss: 0.0361 - val_loss: 0.0236 - 67ms/epoch - 2ms/step
# Epoch 234/300
# 35/35 - 0s - loss: 0.0368 - val_loss: 0.0238 - 68ms/epoch - 2ms/step
# Epoch 235/300
# 35/35 - 0s - loss: 0.0359 - val_loss: 0.0240 - 67ms/epoch - 2ms/step
# Epoch 236/300
# 35/35 - 0s - loss: 0.0365 - val_loss: 0.0238 - 68ms/epoch - 2ms/step
# Epoch 237/300
# 35/35 - 0s - loss: 0.0364 - val_loss: 0.0238 - 68ms/epoch - 2ms/step
# Epoch 238/300
# 35/35 - 0s - loss: 0.0360 - val_loss: 0.0234 - 67ms/epoch - 2ms/step
# Epoch 239/300
# 35/35 - 0s - loss: 0.0359 - val_loss: 0.0233 - 67ms/epoch - 2ms/step
# Epoch 240/300
# 35/35 - 0s - loss: 0.0353 - val_loss: 0.0233 - 69ms/epoch - 2ms/step
# Epoch 241/300
# 35/35 - 0s - loss: 0.0356 - val_loss: 0.0233 - 92ms/epoch - 3ms/step
# Epoch 242/300
# 35/35 - 0s - loss: 0.0345 - val_loss: 0.0235 - 67ms/epoch - 2ms/step
# Epoch 243/300
# 35/35 - 0s - loss: 0.0348 - val_loss: 0.0235 - 68ms/epoch - 2ms/step
# Epoch 244/300
# 35/35 - 0s - loss: 0.0351 - val_loss: 0.0234 - 68ms/epoch - 2ms/step
# Epoch 245/300
# 35/35 - 0s - loss: 0.0361 - val_loss: 0.0234 - 67ms/epoch - 2ms/step
# Epoch 246/300
# 35/35 - 0s - loss: 0.0347 - val_loss: 0.0232 - 67ms/epoch - 2ms/step
# Epoch 247/300
# 35/35 - 0s - loss: 0.0345 - val_loss: 0.0232 - 68ms/epoch - 2ms/step
# Epoch 248/300
# 35/35 - 0s - loss: 0.0346 - val_loss: 0.0233 - 67ms/epoch - 2ms/step
# Epoch 249/300
# 35/35 - 0s - loss: 0.0345 - val_loss: 0.0233 - 69ms/epoch - 2ms/step
# Epoch 250/300
# 35/35 - 0s - loss: 0.0345 - val_loss: 0.0234 - 68ms/epoch - 2ms/step
# Epoch 251/300
# 35/35 - 0s - loss: 0.0337 - val_loss: 0.0234 - 67ms/epoch - 2ms/step
# Epoch 252/300
# 35/35 - 0s - loss: 0.0347 - val_loss: 0.0233 - 68ms/epoch - 2ms/step
# Epoch 253/300
# 35/35 - 0s - loss: 0.0343 - val_loss: 0.0233 - 68ms/epoch - 2ms/step
# Epoch 254/300
# 35/35 - 0s - loss: 0.0344 - val_loss: 0.0231 - 68ms/epoch - 2ms/step
# Epoch 255/300
# 35/35 - 0s - loss: 0.0325 - val_loss: 0.0230 - 66ms/epoch - 2ms/step
# Epoch 256/300
# 35/35 - 0s - loss: 0.0335 - val_loss: 0.0230 - 68ms/epoch - 2ms/step
# Epoch 257/300
# 35/35 - 0s - loss: 0.0341 - val_loss: 0.0229 - 67ms/epoch - 2ms/step
# Epoch 258/300
# 35/35 - 0s - loss: 0.0339 - val_loss: 0.0229 - 67ms/epoch - 2ms/step
# Epoch 259/300
# 35/35 - 0s - loss: 0.0344 - val_loss: 0.0227 - 69ms/epoch - 2ms/step
# Epoch 260/300
# 35/35 - 0s - loss: 0.0342 - val_loss: 0.0228 - 68ms/epoch - 2ms/step
# Epoch 261/300
# 35/35 - 0s - loss: 0.0337 - val_loss: 0.0228 - 68ms/epoch - 2ms/step
# Epoch 262/300
# 35/35 - 0s - loss: 0.0334 - val_loss: 0.0227 - 67ms/epoch - 2ms/step
# Epoch 263/300
# 35/35 - 0s - loss: 0.0341 - val_loss: 0.0226 - 67ms/epoch - 2ms/step
# Epoch 264/300
# 35/35 - 0s - loss: 0.0328 - val_loss: 0.0228 - 68ms/epoch - 2ms/step
# Epoch 265/300
# 35/35 - 0s - loss: 0.0337 - val_loss: 0.0227 - 68ms/epoch - 2ms/step
# Epoch 266/300
# 35/35 - 0s - loss: 0.0333 - val_loss: 0.0227 - 67ms/epoch - 2ms/step
# Epoch 267/300
# 35/35 - 0s - loss: 0.0335 - val_loss: 0.0227 - 68ms/epoch - 2ms/step
# Epoch 268/300
# 35/35 - 0s - loss: 0.0339 - val_loss: 0.0228 - 68ms/epoch - 2ms/step
# Epoch 269/300
# 35/35 - 0s - loss: 0.0325 - val_loss: 0.0229 - 67ms/epoch - 2ms/step
# Epoch 270/300
# 35/35 - 0s - loss: 0.0324 - val_loss: 0.0229 - 68ms/epoch - 2ms/step
# Epoch 271/300
# 35/35 - 0s - loss: 0.0324 - val_loss: 0.0228 - 68ms/epoch - 2ms/step
# Epoch 272/300
# 35/35 - 0s - loss: 0.0330 - val_loss: 0.0227 - 68ms/epoch - 2ms/step
# Epoch 273/300
# 35/35 - 0s - loss: 0.0342 - val_loss: 0.0227 - 68ms/epoch - 2ms/step
# Epoch 274/300
# 35/35 - 0s - loss: 0.0341 - val_loss: 0.0227 - 70ms/epoch - 2ms/step
# Epoch 275/300
# 35/35 - 0s - loss: 0.0322 - val_loss: 0.0227 - 67ms/epoch - 2ms/step
# Epoch 276/300
# 35/35 - 0s - loss: 0.0322 - val_loss: 0.0227 - 67ms/epoch - 2ms/step
# Epoch 277/300
# 35/35 - 0s - loss: 0.0333 - val_loss: 0.0225 - 69ms/epoch - 2ms/step
# Epoch 278/300
# 35/35 - 0s - loss: 0.0332 - val_loss: 0.0224 - 68ms/epoch - 2ms/step
# Epoch 279/300
# 35/35 - 0s - loss: 0.0322 - val_loss: 0.0224 - 69ms/epoch - 2ms/step
# Epoch 280/300
# 35/35 - 0s - loss: 0.0333 - val_loss: 0.0223 - 67ms/epoch - 2ms/step
# Epoch 281/300
# 35/35 - 0s - loss: 0.0323 - val_loss: 0.0224 - 68ms/epoch - 2ms/step
# Epoch 282/300
# 35/35 - 0s - loss: 0.0331 - val_loss: 0.0224 - 69ms/epoch - 2ms/step
# Epoch 283/300
# 35/35 - 0s - loss: 0.0321 - val_loss: 0.0224 - 68ms/epoch - 2ms/step
# Epoch 284/300
# 35/35 - 0s - loss: 0.0328 - val_loss: 0.0224 - 68ms/epoch - 2ms/step
# Epoch 285/300
# 35/35 - 0s - loss: 0.0330 - val_loss: 0.0225 - 68ms/epoch - 2ms/step
# Epoch 286/300
# 35/35 - 0s - loss: 0.0323 - val_loss: 0.0224 - 68ms/epoch - 2ms/step
# Epoch 287/300
# 35/35 - 0s - loss: 0.0329 - val_loss: 0.0224 - 67ms/epoch - 2ms/step
# Epoch 288/300
# 35/35 - 0s - loss: 0.0315 - val_loss: 0.0225 - 68ms/epoch - 2ms/step
# Epoch 289/300
# 35/35 - 0s - loss: 0.0323 - val_loss: 0.0227 - 68ms/epoch - 2ms/step
# Epoch 290/300
# 35/35 - 0s - loss: 0.0321 - val_loss: 0.0225 - 67ms/epoch - 2ms/step
# Epoch 291/300
# 35/35 - 0s - loss: 0.0328 - val_loss: 0.0224 - 68ms/epoch - 2ms/step
# Epoch 292/300
# 35/35 - 0s - loss: 0.0320 - val_loss: 0.0223 - 68ms/epoch - 2ms/step
# Epoch 293/300
# 35/35 - 0s - loss: 0.0322 - val_loss: 0.0221 - 67ms/epoch - 2ms/step
# Epoch 294/300
# 35/35 - 0s - loss: 0.0319 - val_loss: 0.0221 - 68ms/epoch - 2ms/step
# Epoch 295/300
# 35/35 - 0s - loss: 0.0315 - val_loss: 0.0222 - 68ms/epoch - 2ms/step
# Epoch 296/300
# 35/35 - 0s - loss: 0.0314 - val_loss: 0.0222 - 67ms/epoch - 2ms/step
# Epoch 297/300
# 35/35 - 0s - loss: 0.0323 - val_loss: 0.0220 - 68ms/epoch - 2ms/step
# Epoch 298/300
# 35/35 - 0s - loss: 0.0317 - val_loss: 0.0221 - 67ms/epoch - 2ms/step
# Epoch 299/300
# 35/35 - 0s - loss: 0.0336 - val_loss: 0.0222 - 66ms/epoch - 2ms/step
# Epoch 300/300
# 35/35 - 0s - loss: 0.0324 - val_loss: 0.0223 - 68ms/epoch - 2ms/step

# %%
# make a prediction
yhat = model.predict(test_X)
X = test_X.reshape((test_X.shape[0], test_X.shape[2]))

# invert scaling for prediction
dataset_yhat = concatenate((X, yhat), axis=1)
dataset_yhat = scaler.inverse_transform(dataset_yhat)
inv_yhat = dataset_yhat[:, -1]

# invert scaling for actual
y = test_y.reshape((len(test_y), 1))
dataset_y = concatenate((X, y), axis=1)
dataset_y = scaler.inverse_transform(dataset_y)
inv_y = dataset_y[:, -1]
# Out:
# 2023-12-05 02:26:41.131035: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [246,1,11]
# 	 [[{{node Placeholder/_10}}]]
# 2023-12-05 02:26:41.131286: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [246,1,11]
# 	 [[{{node Placeholder/_10}}]]
# 8/8 [==============================] - 1s 930us/step

# %%
date = df['DATE'][train_size:]
num_teams = df['TEAMNAME'].nunique()

fig, ax = plt.subplots()
fig.set_size_inches(18, 6)
ax.plot(date, inv_y / 3600, 
        linestyle='none', 
        marker='s',
        markerfacecolor='cornflowerblue', 
        markeredgecolor='black',
        markersize=7,
        label='Hours spent per day')
# ax.plot(date, inv_yhat / 3600, 
#         linestyle='',
#         marker='o',
#         markersize=5,
#         color='red',
#         label='Prediction')
for i in range(num_teams):
        ax.plot(date.unique(), inv_yhat[i::num_teams] / 3600, 
                linestyle='-',
                marker='o',
                markersize=5,
                # get color from color cycle
                color=ax._get_lines.get_next_color(),
                label=list(codes.keys())[i])
ax.xaxis.set_major_locator(mdates.DayLocator(interval=5))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%b-%d'))
ax.set_xlabel('Date')
ax.set_ylabel('Hours Spent')
plt.xticks(rotation=75)
ax.legend(loc='upper left')
plt.show()

# %%
# MAE
mae = mean_absolute_error(inv_y, inv_yhat) / 3600
print('MAE: %.3f' % (mae))
# Out:
# MAE: 11.222

# %%
# # design network
# np.random.seed(1234)
# tf.random.set_seed(1234)

# tf.keras.utils.set_random_seed(1234)
# tf.config.experimental.enable_op_determinism()

# optim = optimizers.Adam(lr=0.0005, beta_1=0.99, beta_2=0.999, amsgrad=False)
# model = Sequential()
# model.add(LSTM(4, input_shape=(train_X.shape[1], train_X.shape[2])))
# model.add(Dense(1))
# # model.add(Dropout(0.1))
# model.add(Dense(1, activation='sigmoid'))
# model.compile(loss='mae', optimizer=optim)

# # fit network
# history = model.fit(train_X, train_y, epochs=100, batch_size=16, validation_data=(test_X, test_y), verbose=2, shuffle=False)

# # plot history
# plt.plot(history.history['loss'], label='train')
# plt.plot(history.history['val_loss'], label='test')
# plt.legend()
# plt.show()
