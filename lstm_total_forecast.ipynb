# %%
import numpy as np
import pandas as pd
from numpy import hstack
from numpy import concatenate
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import GaussianNoise
from keras.layers import Masking
from keras import optimizers
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

import warnings
warnings.filterwarnings('ignore')

# {'DD': 0.001, 'DP2': 0.0004, 'DP1': 0.00035, 'HP1': 0.00005, 'HP2': 0.0001, 'HD': 0.0002}

# %%
df = pd.read_csv('daily_total.csv')
df['DATE'] = pd.to_datetime(df['DATE'])
df.dtypes
# Out:
# DATE            datetime64[ns]
# USERCOUNT                int64
# SECONDSSPENT             int64
# QUANTITY                 int64
# VOLUME                 float64
# WEIGHT                 float64
# PRICE                  float64
# dtype: object

# %%
df = df[df['DATE'] > '2022-08-10']
# fill missing dates with 0
df.index = df['DATE']
df = df.reindex(pd.date_range(min(df['DATE']), max(df['DATE'])), fill_value=0).drop('DATE', axis=1)
df['SECONDSSPENTNextDay'] = df['SECONDSSPENT'].shift(-1)
df
# Out:
#             USERCOUNT  SECONDSSPENT  QUANTITY       VOLUME         WEIGHT  \
# 2022-08-16         15         24864      1564     5.510447     606.628000
# 2022-08-17         46        648639    153271   900.823306   87245.837728
# 2022-08-18         72       1535976    353781  2687.981897  247269.820740
# 2022-08-19         70       1253113    395921  2944.799061  262781.058485
# 2022-08-20          6         67002       593    14.290446     975.280591
# ...               ...           ...       ...          ...            ...
# 2023-09-25        101       1171721    854092  2678.434373  292547.191456
# 2023-09-26        110       1249771   1016887  3483.392239  371822.547589
# 2023-09-27        104       1257222    939123  2998.222002  300263.198492
# 2023-09-28        109       1339688   1224169  3863.465093  384720.606181
# 2023-09-29        107       1381580   1109442  3556.001516  377380.162562
#
#                  PRICE  SECONDSSPENTNextDay
# 2022-08-16     7714.46             648639.0
# 2022-08-17   731227.04            1535976.0
# 2022-08-18  2135600.74            1253113.0
# 2022-08-19  2136707.30              67002.0
# 2022-08-20    14861.86                  0.0
# ...                ...                  ...
# 2023-09-25  1875797.61            1249771.0
# 2023-09-26  2318629.60            1257222.0
# 2023-09-27  1850064.42            1339688.0
# 2023-09-28  2390796.27            1381580.0
# 2023-09-29  2196789.75                  NaN
#
# [410 rows x 7 columns]

# %%
seconds_spent_next_day = df['SECONDSSPENTNextDay'].values.reshape(-1, 1)
seconds_spent = df['SECONDSSPENT'].values.reshape(-1, 1)
user_count = df['USERCOUNT'].values.reshape(-1, 1)
quantity = df['QUANTITY'].values.reshape(-1, 1)
volume = df['VOLUME'].values.reshape(-1, 1)
weight = df['WEIGHT'].values.reshape(-1, 1)
price = df['PRICE'].values.reshape(-1, 1)

scaler = MinMaxScaler(feature_range=(0, 1))

dataset = scaler.fit_transform(hstack((quantity, volume, weight, price, seconds_spent_next_day)))

# %%
# def df_to_X_y(dataset, window_size=1):
#     # dataset = df.values
#     X = []
#     y = []
#     for i in range(len(dataset) - window_size):
#         row = [[j] for j in dataset[i: i + window_size, :]]
#         # row = dataset[i: i + window_size]
#         X.append(row)
#         y.append(dataset[i + window_size][-1])
#     return np.array(X), np.array(y)

# split = int(len(dataset) * 0.9)
# window_size = 1

# X, y = df_to_X_y(dataset, window_size)
# print(X.shape, y.shape)
# train_X, train_y = X[:split], y[:split]
# test_X, test_y = X[split:], y[split:]

# train_X = train_X.reshape((train_X.shape[0], train_X.shape[1], train_X.shape[3]))
# test_X = test_X.reshape((test_X.shape[0], test_X.shape[1], test_X.shape[3]))

# # train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
# # test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))

# print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)

# %%
# split into train and test sets
window_size = 1
split = int(len(dataset) * 0.9)

train, test = dataset[:-1][:split], dataset[:-1][split:]

train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]

train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (369, 1, 4) (369,) (40, 1, 4) (40,)

# %%
# design network
np.random.seed(1234)
tf.random.set_seed(1234)

tf.keras.utils.set_random_seed(1234)
tf.config.experimental.enable_op_determinism()

optim = optimizers.Adam(lr=0.0001)
model = Sequential()
model.add(Masking(mask_value=0., input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(LSTM(16, input_shape=(train_X.shape[1], train_X.shape[2]), return_sequences=True))
model.add(LSTM(8, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(1))
model.compile(loss='mae', optimizer=optim)

# fit network
history = model.fit(train_X, train_y, epochs=70, batch_size=32, validation_data=(test_X, test_y), verbose=2, shuffle=False)

# plot history
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()
# Out:
# Epoch 1/70
# 2023-12-14 19:26:09.211368: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [369]
# 	 [[{{node Placeholder/_11}}]]
# 2023-12-14 19:26:09.211638: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [369]
# 	 [[{{node Placeholder/_11}}]]
# 2023-12-14 19:26:14.061438: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [40]
# 	 [[{{node Placeholder/_11}}]]
# 2023-12-14 19:26:14.061708: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [40]
# 	 [[{{node Placeholder/_11}}]]
# 12/12 - 6s - loss: 0.3449 - val_loss: 0.2304 - 6s/epoch - 533ms/step
# Epoch 2/70
# 12/12 - 0s - loss: 0.3429 - val_loss: 0.2285 - 52ms/epoch - 4ms/step
# Epoch 3/70
# 12/12 - 0s - loss: 0.3410 - val_loss: 0.2269 - 51ms/epoch - 4ms/step
# Epoch 4/70
# 12/12 - 0s - loss: 0.3394 - val_loss: 0.2256 - 52ms/epoch - 4ms/step
# Epoch 5/70
# 12/12 - 0s - loss: 0.3381 - val_loss: 0.2243 - 51ms/epoch - 4ms/step
# Epoch 6/70
# 12/12 - 0s - loss: 0.3369 - val_loss: 0.2231 - 51ms/epoch - 4ms/step
# Epoch 7/70
# 12/12 - 0s - loss: 0.3359 - val_loss: 0.2219 - 50ms/epoch - 4ms/step
# Epoch 8/70
# 12/12 - 0s - loss: 0.3349 - val_loss: 0.2208 - 50ms/epoch - 4ms/step
# Epoch 9/70
# 12/12 - 0s - loss: 0.3339 - val_loss: 0.2198 - 47ms/epoch - 4ms/step
# Epoch 10/70
# 12/12 - 0s - loss: 0.3330 - val_loss: 0.2187 - 47ms/epoch - 4ms/step
# Epoch 11/70
# 12/12 - 0s - loss: 0.3321 - val_loss: 0.2176 - 45ms/epoch - 4ms/step
# Epoch 12/70
# 12/12 - 0s - loss: 0.3312 - val_loss: 0.2166 - 47ms/epoch - 4ms/step
# Epoch 13/70
# 12/12 - 0s - loss: 0.3302 - val_loss: 0.2154 - 45ms/epoch - 4ms/step
# Epoch 14/70
# 12/12 - 0s - loss: 0.3293 - val_loss: 0.2143 - 46ms/epoch - 4ms/step
# Epoch 15/70
# 12/12 - 0s - loss: 0.3283 - val_loss: 0.2132 - 45ms/epoch - 4ms/step
# Epoch 16/70
# 12/12 - 0s - loss: 0.3273 - val_loss: 0.2120 - 47ms/epoch - 4ms/step
# Epoch 17/70
# 12/12 - 0s - loss: 0.3263 - val_loss: 0.2108 - 45ms/epoch - 4ms/step
# Epoch 18/70
# 12/12 - 0s - loss: 0.3253 - val_loss: 0.2096 - 45ms/epoch - 4ms/step
# Epoch 19/70
# 12/12 - 0s - loss: 0.3242 - val_loss: 0.2084 - 45ms/epoch - 4ms/step
# Epoch 20/70
# 12/12 - 0s - loss: 0.3231 - val_loss: 0.2071 - 44ms/epoch - 4ms/step
# Epoch 21/70
# 12/12 - 0s - loss: 0.3220 - val_loss: 0.2058 - 44ms/epoch - 4ms/step
# Epoch 22/70
# 12/12 - 0s - loss: 0.3209 - val_loss: 0.2045 - 45ms/epoch - 4ms/step
# Epoch 23/70
# 12/12 - 0s - loss: 0.3197 - val_loss: 0.2032 - 44ms/epoch - 4ms/step
# Epoch 24/70
# 12/12 - 0s - loss: 0.3186 - val_loss: 0.2018 - 44ms/epoch - 4ms/step
# Epoch 25/70
# 12/12 - 0s - loss: 0.3174 - val_loss: 0.2004 - 44ms/epoch - 4ms/step
# Epoch 26/70
# 12/12 - 0s - loss: 0.3162 - val_loss: 0.1990 - 45ms/epoch - 4ms/step
# Epoch 27/70
# 12/12 - 0s - loss: 0.3150 - val_loss: 0.1976 - 44ms/epoch - 4ms/step
# Epoch 28/70
# 12/12 - 0s - loss: 0.3138 - val_loss: 0.1961 - 45ms/epoch - 4ms/step
# Epoch 29/70
# 12/12 - 0s - loss: 0.3125 - val_loss: 0.1947 - 44ms/epoch - 4ms/step
# Epoch 30/70
# 12/12 - 0s - loss: 0.3112 - val_loss: 0.1933 - 45ms/epoch - 4ms/step
# Epoch 31/70
# 12/12 - 0s - loss: 0.3098 - val_loss: 0.1919 - 44ms/epoch - 4ms/step
# Epoch 32/70
# 12/12 - 0s - loss: 0.3084 - val_loss: 0.1905 - 45ms/epoch - 4ms/step
# Epoch 33/70
# 12/12 - 0s - loss: 0.3069 - val_loss: 0.1890 - 45ms/epoch - 4ms/step
# Epoch 34/70
# 12/12 - 0s - loss: 0.3054 - val_loss: 0.1874 - 44ms/epoch - 4ms/step
# Epoch 35/70
# 12/12 - 0s - loss: 0.3039 - val_loss: 0.1859 - 45ms/epoch - 4ms/step
# Epoch 36/70
# 12/12 - 0s - loss: 0.3023 - val_loss: 0.1842 - 44ms/epoch - 4ms/step
# Epoch 37/70
# 12/12 - 0s - loss: 0.3007 - val_loss: 0.1826 - 44ms/epoch - 4ms/step
# Epoch 38/70
# 12/12 - 0s - loss: 0.2990 - val_loss: 0.1809 - 44ms/epoch - 4ms/step
# Epoch 39/70
# 12/12 - 0s - loss: 0.2973 - val_loss: 0.1791 - 45ms/epoch - 4ms/step
# Epoch 40/70
# 12/12 - 0s - loss: 0.2955 - val_loss: 0.1773 - 45ms/epoch - 4ms/step
# Epoch 41/70
# 12/12 - 0s - loss: 0.2936 - val_loss: 0.1755 - 45ms/epoch - 4ms/step
# Epoch 42/70
# 12/12 - 0s - loss: 0.2917 - val_loss: 0.1735 - 44ms/epoch - 4ms/step
# Epoch 43/70
# 12/12 - 0s - loss: 0.2897 - val_loss: 0.1716 - 44ms/epoch - 4ms/step
# Epoch 44/70
# 12/12 - 0s - loss: 0.2876 - val_loss: 0.1695 - 45ms/epoch - 4ms/step
# Epoch 45/70
# 12/12 - 0s - loss: 0.2855 - val_loss: 0.1674 - 44ms/epoch - 4ms/step
# Epoch 46/70
# 12/12 - 0s - loss: 0.2833 - val_loss: 0.1652 - 44ms/epoch - 4ms/step
# Epoch 47/70
# 12/12 - 0s - loss: 0.2810 - val_loss: 0.1630 - 45ms/epoch - 4ms/step
# Epoch 48/70
# 12/12 - 0s - loss: 0.2787 - val_loss: 0.1607 - 45ms/epoch - 4ms/step
# Epoch 49/70
# 12/12 - 0s - loss: 0.2763 - val_loss: 0.1584 - 44ms/epoch - 4ms/step
# Epoch 50/70
# 12/12 - 0s - loss: 0.2739 - val_loss: 0.1561 - 44ms/epoch - 4ms/step
# Epoch 51/70
# 12/12 - 0s - loss: 0.2715 - val_loss: 0.1537 - 44ms/epoch - 4ms/step
# Epoch 52/70
# 12/12 - 0s - loss: 0.2692 - val_loss: 0.1513 - 44ms/epoch - 4ms/step
# Epoch 53/70
# 12/12 - 0s - loss: 0.2668 - val_loss: 0.1488 - 44ms/epoch - 4ms/step
# Epoch 54/70
# 12/12 - 0s - loss: 0.2644 - val_loss: 0.1463 - 44ms/epoch - 4ms/step
# Epoch 55/70
# 12/12 - 0s - loss: 0.2620 - val_loss: 0.1438 - 45ms/epoch - 4ms/step
# Epoch 56/70
# 12/12 - 0s - loss: 0.2595 - val_loss: 0.1412 - 45ms/epoch - 4ms/step
# Epoch 57/70
# 12/12 - 0s - loss: 0.2569 - val_loss: 0.1385 - 45ms/epoch - 4ms/step
# Epoch 58/70
# 12/12 - 0s - loss: 0.2543 - val_loss: 0.1360 - 45ms/epoch - 4ms/step
# Epoch 59/70
# 12/12 - 0s - loss: 0.2517 - val_loss: 0.1335 - 45ms/epoch - 4ms/step
# Epoch 60/70
# 12/12 - 0s - loss: 0.2490 - val_loss: 0.1310 - 44ms/epoch - 4ms/step
# Epoch 61/70
# 12/12 - 0s - loss: 0.2463 - val_loss: 0.1284 - 45ms/epoch - 4ms/step
# Epoch 62/70
# 12/12 - 0s - loss: 0.2435 - val_loss: 0.1257 - 44ms/epoch - 4ms/step
# Epoch 63/70
# 12/12 - 0s - loss: 0.2407 - val_loss: 0.1231 - 45ms/epoch - 4ms/step
# Epoch 64/70
# 12/12 - 0s - loss: 0.2380 - val_loss: 0.1205 - 44ms/epoch - 4ms/step
# Epoch 65/70
# 12/12 - 0s - loss: 0.2351 - val_loss: 0.1181 - 44ms/epoch - 4ms/step
# Epoch 66/70
# 12/12 - 0s - loss: 0.2323 - val_loss: 0.1156 - 44ms/epoch - 4ms/step
# Epoch 67/70
# 12/12 - 0s - loss: 0.2295 - val_loss: 0.1132 - 44ms/epoch - 4ms/step
# Epoch 68/70
# 12/12 - 0s - loss: 0.2268 - val_loss: 0.1109 - 44ms/epoch - 4ms/step
# Epoch 69/70
# 12/12 - 0s - loss: 0.2243 - val_loss: 0.1091 - 44ms/epoch - 4ms/step
# Epoch 70/70
# 12/12 - 0s - loss: 0.2218 - val_loss: 0.1083 - 44ms/epoch - 4ms/step

# %%
# make a prediction
yhat = model.predict(test_X)
X = test_X.reshape((test_X.shape[0], test_X.shape[2]))
print(X.shape, yhat.shape)

# invert scaling for forecast
inv_yhat = concatenate((X, yhat), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:, -1]

# invert scaling for actual
y = test_y.reshape((len(test_y), 1))
dataset_y = concatenate((X, y), axis=1)
dataset_y = scaler.inverse_transform(dataset_y)
inv_y = dataset_y[:, -1]
# inv_y = scaler.inverse_transform(test_y)
# inv_y = inv_y[:, -1]
# Out:
# 2023-12-14 19:26:18.912482: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [40,1,4]
# 	 [[{{node Placeholder/_10}}]]
# 2023-12-14 19:26:18.912706: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [40,1,4]
# 	 [[{{node Placeholder/_10}}]]
# 2/2 [==============================] - 1s 2ms/step
# (40, 4) (40, 1)

# %%
df['DATE'] = df.index
date = df['DATE'][split + window_size:]

fig, ax = plt.subplots()
fig.set_size_inches(18, 6)
ax.plot(date, inv_y / 3600, 
        linestyle='none', 
        marker='s',
        markerfacecolor='cornflowerblue', 
        markeredgecolor='black',
        markersize=7,
        label='Hours spent per day')
ax.plot(date, inv_yhat / 3600, 
        linestyle='-',
        marker='o',
        markersize=5,
        color='red',
        label='Prediction')
ax.xaxis.set_major_locator(mdates.DayLocator(interval=5))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%b-%d'))
ax.set_xlabel('Date')
ax.set_ylabel('Hours Spent')
plt.xticks(rotation=75)
ax.legend(loc='upper left')
plt.show()

# %%
# MAE
mae = mean_absolute_error(inv_y[:-1], inv_yhat[1:]) / 3600
print('MAE: %.3f' % (mae))
# Out:
# MAE: 50.172

# %%
last = dataset[-1, :-1].reshape((1, test_X.shape[1], test_X.shape[2]))

# make a prediction
forecast = model.predict(last)
X = last.reshape((last.shape[0], last.shape[2]))
print(X.shape, forecast.shape)

# invert scaling for forecast
inv_forecast = concatenate((X, forecast), axis=1)
inv_forecast = scaler.inverse_transform(inv_forecast)
inv_forecast = inv_forecast[:, -1]
# Out:
# 1/1 [==============================] - 0s 25ms/step
# (1, 4) (1, 1)
# 2023-12-14 19:26:20.553775: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,1,4]
# 	 [[{{node Placeholder/_10}}]]
# 2023-12-14 19:26:20.554036: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,1,4]
# 	 [[{{node Placeholder/_10}}]]

# %%
print('Actual: %.3f' % (df['SECONDSSPENT'][-1] / 3600))
print('Forecast: %.3f' % (inv_forecast / 3600))
# Out:
# Actual: 383.772
# Forecast: 308.055

# %%
# wo wl hr
# task type: mar
