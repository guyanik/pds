# %%
import numpy as np
import pandas as pd
import xgboost as xgb
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import accuracy_score
from matplotlib import pyplot as plt
import matplotlib.dates as mdates

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('daily_total.csv')
df['DATE'] = pd.to_datetime(df['DATE'])
df.dtypes
# Out:
# DATE            datetime64[ns]
# USERCOUNT                int64
# SECONDSSPENT             int64
# QUANTITY                 int64
# VOLUME                 float64
# WEIGHT                 float64
# PRICE                  float64
# dtype: object

# %%
df = df[df['DATE'] > '2022-08-10']

# %%
codes = dict(zip(df['DATE'].unique(), range(1, len(df['DATE'].unique())+1)))
df['DATE'] = df['DATE'].map(codes)
print(codes)
df
# Out:
# {numpy.datetime64('2022-08-16T00:00:00.000000000'): 1, numpy.datetime64('2022-08-17T00:00:00.000000000'): 2, numpy.datetime64('2022-08-18T00:00:00.000000000'): 3, numpy.datetime64('2022-08-19T00:00:00.000000000'): 4, numpy.datetime64('2022-08-20T00:00:00.000000000'): 5, numpy.datetime64('2022-08-22T00:00:00.000000000'): 6, numpy.datetime64('2022-08-23T00:00:00.000000000'): 7, numpy.datetime64('2022-08-24T00:00:00.000000000'): 8, numpy.datetime64('2022-08-25T00:00:00.000000000'): 9, numpy.datetime64('2022-08-26T00:00:00.000000000'): 10, numpy.datetime64('2022-08-27T00:00:00.000000000'): 11, numpy.datetime64('2022-08-29T00:00:00.000000000'): 12, numpy.datetime64('2022-08-30T00:00:00.000000000'): 13, numpy.datetime64('2022-08-31T00:00:00.000000000'): 14, numpy.datetime64('2022-09-01T00:00:00.000000000'): 15, numpy.datetime64('2022-09-02T00:00:00.000000000'): 16, numpy.datetime64('2022-09-03T00:00:00.000000000'): 17, numpy.datetime64('2022-09-05T00:00:00.000000000'): 18, numpy.datetime64('2022-09-06T00:00:00.000000000'): 19, numpy.datetime64('2022-09-07T00:00:00.000000000'): 20, numpy.datetime64('2022-09-08T00:00:00.000000000'): 21, numpy.datetime64('2022-09-09T00:00:00.000000000'): 22, numpy.datetime64('2022-09-10T00:00:00.000000000'): 23, numpy.datetime64('2022-09-12T00:00:00.000000000'): 24, numpy.datetime64('2022-09-13T00:00:00.000000000'): 25, numpy.datetime64('2022-09-14T00:00:00.000000000'): 26, numpy.datetime64('2022-09-15T00:00:00.000000000'): 27, numpy.datetime64('2022-09-16T00:00:00.000000000'): 28, numpy.datetime64('2022-09-17T00:00:00.000000000'): 29, numpy.datetime64('2022-09-19T00:00:00.000000000'): 30, numpy.datetime64('2022-09-20T00:00:00.000000000'): 31, numpy.datetime64('2022-09-21T00:00:00.000000000'): 32, numpy.datetime64('2022-09-22T00:00:00.000000000'): 33, numpy.datetime64('2022-09-23T00:00:00.000000000'): 34, numpy.datetime64('2022-09-24T00:00:00.000000000'): 35, numpy.datetime64('2022-09-26T00:00:00.000000000'): 36, numpy.datetime64('2022-09-27T00:00:00.000000000'): 37, numpy.datetime64('2022-09-28T00:00:00.000000000'): 38, numpy.datetime64('2022-09-29T00:00:00.000000000'): 39, numpy.datetime64('2022-10-01T00:00:00.000000000'): 40, numpy.datetime64('2022-10-03T00:00:00.000000000'): 41, numpy.datetime64('2022-10-04T00:00:00.000000000'): 42, numpy.datetime64('2022-10-05T00:00:00.000000000'): 43, numpy.datetime64('2022-10-06T00:00:00.000000000'): 44, numpy.datetime64('2022-10-07T00:00:00.000000000'): 45, numpy.datetime64('2022-10-08T00:00:00.000000000'): 46, numpy.datetime64('2022-10-10T00:00:00.000000000'): 47, numpy.datetime64('2022-10-11T00:00:00.000000000'): 48, numpy.datetime64('2022-10-12T00:00:00.000000000'): 49, numpy.datetime64('2022-10-13T00:00:00.000000000'): 50, numpy.datetime64('2022-10-14T00:00:00.000000000'): 51, numpy.datetime64('2022-10-15T00:00:00.000000000'): 52, numpy.datetime64('2022-10-17T00:00:00.000000000'): 53, numpy.datetime64('2022-10-18T00:00:00.000000000'): 54, numpy.datetime64('2022-10-19T00:00:00.000000000'): 55, numpy.datetime64('2022-10-20T00:00:00.000000000'): 56, numpy.datetime64('2022-10-21T00:00:00.000000000'): 57, numpy.datetime64('2022-10-24T00:00:00.000000000'): 58, numpy.datetime64('2022-10-25T00:00:00.000000000'): 59, numpy.datetime64('2022-10-26T00:00:00.000000000'): 60, numpy.datetime64('2022-10-27T00:00:00.000000000'): 61, numpy.datetime64('2022-10-28T00:00:00.000000000'): 62, numpy.datetime64('2022-10-31T00:00:00.000000000'): 63, numpy.datetime64('2022-11-02T00:00:00.000000000'): 64, numpy.datetime64('2022-11-03T00:00:00.000000000'): 65, numpy.datetime64('2022-11-04T00:00:00.000000000'): 66, numpy.datetime64('2022-11-07T00:00:00.000000000'): 67, numpy.datetime64('2022-11-08T00:00:00.000000000'): 68, numpy.datetime64('2022-11-09T00:00:00.000000000'): 69, numpy.datetime64('2022-11-10T00:00:00.000000000'): 70, numpy.datetime64('2022-11-14T00:00:00.000000000'): 71, numpy.datetime64('2022-11-15T00:00:00.000000000'): 72, numpy.datetime64('2022-11-16T00:00:00.000000000' ...
#       DATE  USERCOUNT  SECONDSSPENT  QUANTITY       VOLUME         WEIGHT  \
# 964      1         15         24864      1564     5.510447     606.628000
# 965      2         46        648639    153271   900.823306   87245.837728
# 966      3         72       1535976    353781  2687.981897  247269.820740
# 967      4         70       1253113    395921  2944.799061  262781.058485
# 968      5          6         67002       593    14.290446     975.280591
# ...    ...        ...           ...       ...          ...            ...
# 1258   295        101       1171721    854092  2678.434373  292547.191456
# 1259   296        110       1249771   1016887  3483.392239  371822.547589
# 1260   297        104       1257222    939123  2998.222002  300263.198492
# 1261   298        109       1339688   1224169  3863.465093  384720.606181
# 1262   299        107       1381580   1109442  3556.001516  377380.162562
#
#            PRICE
# 964      7714.46
# 965    731227.04
# 966   2135600.74
# 967   2136707.30
# 968     14861.86
# ...          ...
# 1258  1875797.61
# 1259  2318629.60
# 1260  1850064.42
# 1261  2390796.27
# 1262  2196789.75
#
# [299 rows x 7 columns]

# %%
# correlation matrix
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_403ac_row0_col0, #T_403ac_row1_col1, #T_403ac_row2_col2, #T_403ac_row3_col3, #T_403ac_row4_col4, #T_403ac_row5_col5, #T_403ac_row6_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_403ac_row0_col1, #T_403ac_row0_col2, #T_403ac_row0_col3, #T_403ac_row0_col4, #T_403ac_row0_col5, #T_403ac_row0_col6, #T_403ac_row3_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_403ac_row1_col0 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_403ac_row1_col2 {
#   background-color: #d75445;
#   color: #f1f1f1;
# }
# #T_403ac_row1_col3 {
#   background-color: #e9785d;
#   color: #f1f1f1;
# }
# #T_403ac_row1_col4 {
#   background-color: #f39475;
#   color: #000000;
# }
# #T_403ac_row1_col5 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_403ac_row1_col6 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_403ac_row2_col0 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_403ac_row2_col1 {
#   background-color: #de614d;
#   color: #f1f1f1;
# }
# #T_403ac_row2_col3 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_403ac_row2_col4, #T_403ac_row4_col3 {
#   background-color: #e8765c;
#   color: #f1f1f1;
# }
# #T_403ac_row2_col5 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_403ac_row2_col6 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_403ac_row3_col1 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_403ac_row3_col2 {
#   background-color: #e16751;
#   color: #f1f1f1;
# }
# #T_403ac_row3_col4 {
#   background-color: #ed8366;
#   color: #f1f1f1;
# }
# #T_403ac_row3_col5 {
#   background-color: #d24b40;
#   color: #f1f1f1;
# }
# #T_403ac_row3_col6 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_403ac_row4_col0 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_403ac_row4_col1 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_403ac_row4_col2 {
#   background-color: #e36c55;
#   color: #f1f1f1;
# }
# #T_403ac_row4_col5 {
#   background-color: #c32e31;
#   color: #f1f1f1;
# }
# #T_403ac_row4_col6 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_403ac_row5_col0 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_403ac_row5_col1 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_403ac_row5_col2 {
#   background-color: #d85646;
#   color: #f1f1f1;
# }
# #T_403ac_row5_col3 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# #T_403ac_row5_col4 {
#   background-color: #c43032;
#   color: #f1f1f1;
# }
# #T_403ac_row5_col6 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_403ac_row6_col0 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_403ac_row6_col1 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_403ac_row6_col2 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_403ac_row6_col3 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_403ac_row6_col4 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_403ac_row6_col5 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# </style>
# <table id="T_403ac">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_403ac_level0_col0" class="col_heading level0 col0" >DATE</th>
#       <th id="T_403ac_level0_col1" class="col_heading level0 col1" >USERCOUNT</th>
#       <th id="T_403ac_level0_col2" class="col_heading level0 col2" >SECONDSSPENT</th>
#       <th id="T_403ac_level0_col3" class="col_heading level0 col3" >QUANTITY</th>
#       <th id="T_403ac_level0_col4" class="col_heading level0 col4" >VOLUME</th>
#       <th id="T_403ac_level0_col5" class="col_heading level0 col5" >WEIGHT</th>
#       <th id="T_403ac_level0_col6" class="col_heading level0 col6" >PRICE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_403ac_level0_row0" class="row_heading level0 row0" >DATE</th>
#       <td id="T_403ac_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_403ac_row0_col1" class="data row0 col1" >-0.218943</td>
#       <td id="T_403ac_row0_col2" class="data row0 col2" >-0.510317</td>
#       <td id="T_403ac_row0_col3" class="data row0 col3" >-0.552823</td>
#       <td id="T_403ac_row0_col4" class="data row0 col4" >-0.334129</td>
#       <td id="T_403ac_row0_col5" class="data row0 col5" >-0.432707</td>
#       <td id="T_403ac_row0_col6" class="data row0 col6" >-0.167726</td>
#     </tr>
#     <tr>
#       <th id="T_403ac_level0_row1" class="row_heading level0 row1" >USERCOUNT</th>
#       <td id="T_403ac_row1_col0" class="data row1 col0" >-0.218943</td>
#       <td id="T_403ac_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_403ac_row1_col2" class="data row1 col2" >0.845610</td>
#       <td id="T_403ac_row1_col3" class="data row1 col3" >0.731339</td>
#       <td id="T_403ac_row1_col4" class="data row1 col4" >0.683897</td>
#       <td id="T_403ac_row1_col5" class="data row1 col5" >0.738980</td>
#       <td id="T_403ac_row1_col6" class="data row1 col6" >0.429018</td>
#     </tr>
#     <tr>
#       <th id="T_403ac_level0_row2" class="row_heading level0 row2" >SECONDSSPENT</th>
#       <td id="T_403ac_row2_col0" class="data row2 col0" >-0.510317</td>
#       <td id="T_403ac_row2_col1" class="data row2 col1" >0.845610</td>
#       <td id="T_403ac_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_403ac_row2_col3" class="data row2 col3" >0.788504</td>
#       <td id="T_403ac_row2_col4" class="data row2 col4" >0.771896</td>
#       <td id="T_403ac_row2_col5" class="data row2 col5" >0.837530</td>
#       <td id="T_403ac_row2_col6" class="data row2 col6" >0.476098</td>
#     </tr>
#     <tr>
#       <th id="T_403ac_level0_row3" class="row_heading level0 row3" >QUANTITY</th>
#       <td id="T_403ac_row3_col0" class="data row3 col0" >-0.552823</td>
#       <td id="T_403ac_row3_col1" class="data row3 col1" >0.731339</td>
#       <td id="T_403ac_row3_col2" class="data row3 col2" >0.788504</td>
#       <td id="T_403ac_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_403ac_row3_col4" class="data row3 col4" >0.734363</td>
#       <td id="T_403ac_row3_col5" class="data row3 col5" >0.875143</td>
#       <td id="T_403ac_row3_col6" class="data row3 col6" >0.368323</td>
#     </tr>
#     <tr>
#       <th id="T_403ac_level0_row4" class="row_heading level0 row4" >VOLUME</th>
#       <td id="T_403ac_row4_col0" class="data row4 col0" >-0.334129</td>
#       <td id="T_403ac_row4_col1" class="data row4 col1" >0.683897</td>
#       <td id="T_403ac_row4_col2" class="data row4 col2" >0.771896</td>
#       <td id="T_403ac_row4_col3" class="data row4 col3" >0.734363</td>
#       <td id="T_403ac_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_403ac_row4_col5" class="data row4 col5" >0.941847</td>
#       <td id="T_403ac_row4_col6" class="data row4 col6" >0.555112</td>
#     </tr>
#     <tr>
#       <th id="T_403ac_level0_row5" class="row_heading level0 row5" >WEIGHT</th>
#       <td id="T_403ac_row5_col0" class="data row5 col0" >-0.432707</td>
#       <td id="T_403ac_row5_col1" class="data row5 col1" >0.738980</td>
#       <td id="T_403ac_row5_col2" class="data row5 col2" >0.837530</td>
#       <td id="T_403ac_row5_col3" class="data row5 col3" >0.875143</td>
#       <td id="T_403ac_row5_col4" class="data row5 col4" >0.941847</td>
#       <td id="T_403ac_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_403ac_row5_col6" class="data row5 col6" >0.518276</td>
#     </tr>
#     <tr>
#       <th id="T_403ac_level0_row6" class="row_heading level0 row6" >PRICE</th>
#       <td id="T_403ac_row6_col0" class="data row6 col0" >-0.167726</td>
#       <td id="T_403ac_row6_col1" class="data row6 col1" >0.429018</td>
#       <td id="T_403ac_row6_col2" class="data row6 col2" >0.476098</td>
#       <td id="T_403ac_row6_col3" class="data row6 col3" >0.368323</td>
#       <td id="T_403ac_row6_col4" class="data row6 col4" >0.555112</td>
#       <td id="T_403ac_row6_col5" class="data row6 col5" >0.518276</td>
#       <td id="T_403ac_row6_col6" class="data row6 col6" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# split into train and test sets
cols = ['QUANTITY', 'VOLUME', 'WEIGHT', 'PRICE']

train_size = int(len(df) * 0.8)
test_size = len(df) - train_size
train, test = df[:train_size], df[train_size:]
train_X, train_y = train[cols], train['SECONDSSPENT']
test_X, test_y = test[cols], test['SECONDSSPENT']

# %%
dtrain_reg = xgb.DMatrix(train_X, train_y, enable_categorical=True)
dtest_reg = xgb.DMatrix(test_X, test_y, enable_categorical=True)

# %%
params = {"objective": "reg:squarederror", 
          "tree_method": "hist", 
          "learning_rate": 0.001, 
          "max_depth": 1,
          "subsample": 0.8,
          "colsample_bytree": 0.8,
          "seed": 1234, 
          "eval_metric": "mae"}
evals = [(dtrain_reg, "train"), (dtest_reg, "test")]
n = 10000

model = xgb.train(
   params=params,
   dtrain=dtrain_reg,
   num_boost_round=n,
   evals=evals,
   verbose_eval=50,
   early_stopping_rounds=50
)
# Out:
# [0]	train-mae:1778724.86795	test-mae:1017168.00632
# [50]	train-mae:1693733.76780	test-mae:964806.35618
# [100]	train-mae:1613631.89314	test-mae:913373.86458
# [150]	train-mae:1537444.25667	test-mae:865409.87083
# [200]	train-mae:1465275.28360	test-mae:818337.34557
# [250]	train-mae:1397228.34401	test-mae:772272.10104
# [300]	train-mae:1332125.82741	test-mae:730401.40312
# [350]	train-mae:1270498.86140	test-mae:689309.60833
# [400]	train-mae:1211656.48130	test-mae:651826.45417
# [450]	train-mae:1155943.00968	test-mae:614259.96250
# [500]	train-mae:1103132.50092	test-mae:579795.68073
# [550]	train-mae:1052925.78347	test-mae:546530.44740
# [600]	train-mae:1005004.82976	test-mae:515265.13542
# [650]	train-mae:959741.03177	test-mae:486389.31562
# [700]	train-mae:916107.69901	test-mae:460315.56250
# [750]	train-mae:874954.17050	test-mae:434616.13854
# [800]	train-mae:835743.62317	test-mae:411484.41042
# [850]	train-mae:798392.41763	test-mae:388439.95104
# [900]	train-mae:763264.89644	test-mae:368737.93333
# [950]	train-mae:729471.26621	test-mae:350479.65104
# [1000]	train-mae:698053.72333	test-mae:333570.45208
# [1050]	train-mae:668468.51098	test-mae:318118.78229
# [1100]	train-mae:640426.34702	test-mae:303720.05833
# [1150]	train-mae:614385.91135	test-mae:289625.69062
# [1200]	train-mae:589504.61585	test-mae:276223.35729
# [1250]	train-mae:566418.75732	test-mae:265465.22917
# [1300]	train-mae:544686.30805	test-mae:253939.17396
# [1350]	train-mae:524276.66423	test-mae:243872.58333
# [1400]	train-mae:504923.60983	test-mae:236099.26771
# [1450]	train-mae:486479.34153	test-mae:230023.33021
# [1500]	train-mae:468922.76098	test-mae:223214.16875
# [1550]	train-mae:453081.73196	test-mae:218450.54583
# [1600]	train-mae:438112.91789	test-mae:213478.07083
# [1650]	train-mae:424207.97803	test-mae:209274.34479
# [1700]	train-mae:411074.95999	test-mae:205588.98438
# [1750]	train-mae:398662.11611	test-mae:202090.45208
# [1800]	train-mae:387364.61559	test-mae:199317.29062
# [1850]	train-mae:376911.53217	test-mae:196648.22292
# [1900]	train-mae:366807.07453	test-mae:194169.62812
# [1950]	train-mae:357533.89147	test-mae:192547.07604
# [2000]	train-mae:348909.01804	test-mae:189662.01146
# [2050]	train-mae:340901.86637	test-mae:187699.81042
# [2100]	train-mae:333351.60774	test-mae:186550.75937
# [2150]	train-mae:326367.08473	test-mae:185754.39688
# [2200]	train-mae:319889.85957	test-mae:184937.91979
# [2250]	train-mae:313855.03426	test-mae:184109.89479
# [2300]	train-mae:308166.46548	test-mae:183074.54583
# [2350]	train-mae:302771.02772	test-mae:182459.21875
# [2400]	train-mae:297762.97490	test-mae:182323.14062
# [2450]	train-mae:293245.34623	test-mae:182098.85625
# [2500]	train-mae:289070.78190	test-mae:181676.10625
# [2550]	train-mae:285229.35617	test-mae:180963.26042
# [2600]	train-mae:281729.39932	test-mae:180990.65208
# [2642]	train-mae:279023.00000	test-mae:181013.57292

# %%
xgb.plot_importance(model)
plt.figure(figsize = (16, 12))
plt.show()

# %%
yhat = model.predict(dtest_reg)
date = df.index[train_size:]

fig, ax = plt.subplots()
fig.set_size_inches(18, 6)
ax.plot(date, test_y / 3600, 
        linestyle='none', 
        marker='s',
        markerfacecolor='cornflowerblue', 
        markeredgecolor='black',
        markersize=7,
        label='Test')
ax.plot(date, yhat / 3600, 
        linestyle='-',
        marker='o',
        markersize=3,
        color='red',
        label='Prediction')
ax.xaxis.set_major_locator(mdates.DayLocator(interval=5))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%b-%d'))
ax.set_xlabel('Date')
ax.set_ylabel('Hours spent')
plt.xticks(rotation=75)
ax.legend(loc='upper right')
plt.show()

mae = mean_absolute_error(test_y, yhat) / 3600
print('MAE: %.3f' % mae)
# Out:
# MAE: 50.282
