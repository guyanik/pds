# %%
import numpy as np
import pandas as pd
from numpy import hstack
from numpy import concatenate
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import GaussianNoise
from keras.layers import Masking
from keras import optimizers
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

import warnings
warnings.filterwarnings('ignore')

# {'DD': 0.001, 'DP2': 0.0004, 'DP1': 0.00035, 'HP1': 0.00005, 'HP2': 0.0001, 'HD': 0.0002}

# %%
df = pd.read_csv('daily_total.csv')
df['DATE'] = pd.to_datetime(df['DATE'])
df.dtypes
# Out:
# DATE            datetime64[ns]
# USERCOUNT                int64
# SECONDSSPENT             int64
# QUANTITY                 int64
# VOLUME                 float64
# WEIGHT                 float64
# PRICE                  float64
# dtype: object

# %%
df = df[df['DATE'] > '2022-08-10']
# fill missing dates with 0
df.index = df['DATE']
df = df.reindex(pd.date_range(min(df['DATE']), max(df['DATE'])), fill_value=0).drop('DATE', axis=1)
df['DATE'] = df.index
df
# Out:
#             USERCOUNT  SECONDSSPENT  QUANTITY       VOLUME         WEIGHT  \
# 2022-08-16         15         24864      1564     5.510447     606.628000
# 2022-08-17         46        648639    153271   900.823306   87245.837728
# 2022-08-18         72       1535976    353781  2687.981897  247269.820740
# 2022-08-19         70       1253113    395921  2944.799061  262781.058485
# 2022-08-20          6         67002       593    14.290446     975.280591
# ...               ...           ...       ...          ...            ...
# 2023-09-25        101       1171721    854092  2678.434373  292547.191456
# 2023-09-26        110       1249771   1016887  3483.392239  371822.547589
# 2023-09-27        104       1257222    939123  2998.222002  300263.198492
# 2023-09-28        109       1339688   1224169  3863.465093  384720.606181
# 2023-09-29        107       1381580   1109442  3556.001516  377380.162562
#
#                  PRICE       DATE
# 2022-08-16     7714.46 2022-08-16
# 2022-08-17   731227.04 2022-08-17
# 2022-08-18  2135600.74 2022-08-18
# 2022-08-19  2136707.30 2022-08-19
# 2022-08-20    14861.86 2022-08-20
# ...                ...        ...
# 2023-09-25  1875797.61 2023-09-25
# 2023-09-26  2318629.60 2023-09-26
# 2023-09-27  1850064.42 2023-09-27
# 2023-09-28  2390796.27 2023-09-28
# 2023-09-29  2196789.75 2023-09-29
#
# [410 rows x 7 columns]

# %%
seconds_spent = df['SECONDSSPENT'].values.reshape(-1, 1)
user_count = df['USERCOUNT'].values.reshape(-1, 1)
quantity = df['QUANTITY'].values.reshape(-1, 1)
volume = df['VOLUME'].values.reshape(-1, 1)
weight = df['WEIGHT'].values.reshape(-1, 1)
price = df['PRICE'].values.reshape(-1, 1)

scaler = MinMaxScaler(feature_range=(0, 1))
# seconds_spent = scaler.fit_transform(seconds_spent)
# user_count = scaler.fit_transform(user_count)
# quantity = scaler.fit_transform(quantity)
# volume = scaler.fit_transform(volume)
# weight = scaler.fit_transform(weight)
# price = scaler.fit_transform(price)

dataset = scaler.fit_transform(hstack((user_count, quantity, volume, weight, price, seconds_spent)))

# %%
# split into train and test sets
train_size = int(len(dataset) * 0.8)
test_size = len(dataset) - train_size
train, test = dataset[:train_size, :], dataset[train_size:, :]

train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]

train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (328, 1, 5) (328,) (82, 1, 5) (82,)

# %%
# design network
np.random.seed(1234)
tf.random.set_seed(1234)

tf.keras.utils.set_random_seed(1234)
tf.config.experimental.enable_op_determinism()

optim = optimizers.Adam(lr=0.0005)
model = Sequential()
model.add(Masking(mask_value=0., input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(LSTM(16, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(1))
model.add(Dropout(0.1))
model.add(Dense(1, activation='linear'))
model.compile(loss='mae', optimizer=optim)

# fit network
history = model.fit(train_X, train_y, epochs=100, batch_size=64, validation_data=(test_X, test_y), verbose=2, shuffle=False)

# plot history
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 2023-12-05 03:03:35.249506: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [328]
# 	 [[{{node Placeholder/_11}}]]
# 2023-12-05 03:03:35.249775: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [328]
# 	 [[{{node Placeholder/_11}}]]
# 2023-12-05 03:03:38.065778: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [82]
# 	 [[{{node Placeholder/_11}}]]
# 2023-12-05 03:03:38.066033: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape
ms/step
# Epoch 52/100
# 6/6 - 0s - loss: 0.1095 - val_loss: 0.0563 - 31ms/epoch - 5ms/step
# Epoch 53/100
# 6/6 - 0s - loss: 0.1119 - val_loss: 0.0547 - 30ms/epoch - 5ms/step
# Epoch 54/100
# 6/6 - 0s - loss: 0.1010 - val_loss: 0.0534 - 31ms/epoch - 5ms/step
# Epoch 55/100
# 6/6 - 0s - loss: 0.0900 - val_loss: 0.0524 - 31ms/epoch - 5ms/step
# Epoch 56/100
# 6/6 - 0s - loss: 0.1001 - val_loss: 0.0514 - 31ms/epoch - 5ms/step
# Epoch 57/100
# 6/6 - 0s - loss: 0.1124 - val_loss: 0.0502 - 31ms/epoch - 5ms/step
# Epoch 58/100
# 6/6 - 0s - loss: 0.1070 - val_loss: 0.0491 - 32ms/epoch - 5ms/step
# Epoch 59/100
# 6/6 - 0s - loss: 0.0951 - val_loss: 0.0481 - 38ms/epoch - 6ms/step
# Epoch 60/100
# 6/6 - 0s - loss: 0.1015 - val_loss: 0.0471 - 43ms/epoch - 7ms/step
# Epoch 61/100
# 6/6 - 0s - loss: 0.0925 - val_loss: 0.0461 - 31ms/epoch - 5ms/step
# Epoch 62/100
# 6/6 - 0s - loss: 0.0968 - val_loss: 0.0452 - 31ms/epoch - 5ms/step
# Epoch 63/100
# 6/6 - 0s - loss: 0.1135 - val_loss: 0.0443 - 31ms/epoch - 5ms/step
# Epoch 64/100
# 6/6 - 0s - loss: 0.0908 - val_loss: 0.0434 - 30ms/epoch - 5ms/step
# Epoch 65/100
# 6/6 - 0s - loss: 0.0971 - val_loss: 0.0425 - 31ms/epoch - 5ms/step
# Epoch 66/100
# 6/6 - 0s - loss: 0.1002 - val_loss: 0.0415 - 30ms/epoch - 5ms/step
# Epoch 67/100
# 6/6 - 0s - loss: 0.0909 - val_loss: 0.0408 - 30ms/epoch - 5ms/step
# Epoch 68/100
# 6/6 - 0s - loss: 0.0917 - val_loss: 0.0400 - 31ms/epoch - 5ms/step
# Epoch 69/100
# 6/6 - 0s - loss: 0.0916 - val_loss: 0.0392 - 31ms/epoch - 5ms/step
# Epoch 70/100
# 6/6 - 0s - loss: 0.0906 - val_loss: 0.0385 - 30ms/epoch - 5ms/step
# Epoch 71/100
# 6/6 - 0s - loss: 0.0838 - val_loss: 0.0377 - 31ms/epoch - 5ms/step
# Epoch 72/100
# 6/6 - 0s - loss: 0.0849 - val_loss: 0.0371 - 31ms/epoch - 5ms/step
# Epoch 73/100
# 6/6 - 0s - loss: 0.0881 - val_loss: 0.0364 - 31ms/epoch - 5ms/step
# Epoch 74/100
# 6/6 - 0s - loss: 0.0884 - val_loss: 0.0355 - 30ms/epoch - 5ms/step
# Epoch 75/100
# 6/6 - 0s - loss: 0.0839 - val_loss: 0.0345 - 31ms/epoch - 5ms/step
# Epoch 76/100
# 6/6 - 0s - loss: 0.0897 - val_loss: 0.0337 - 30ms/epoch - 5ms/step
# Epoch 77/100
# 6/6 - 0s - loss: 0.0877 - val_loss: 0.0330 - 30ms/epoch - 5ms/step
# Epoch 78/100
# 6/6 - 0s - loss: 0.0853 - val_loss: 0.0323 - 31ms/epoch - 5ms/step
# Epoch 79/100
# 6/6 - 0s - loss: 0.0782 - val_loss: 0.0316 - 31ms/epoch - 5ms/step
# Epoch 80/100
# 6/6 - 0s - loss: 0.0950 - val_loss: 0.0310 - 33ms/epoch - 6ms/step
# Epoch 81/100
# 6/6 - 0s - loss: 0.0822 - val_loss: 0.0305 - 33ms/epoch - 6ms/step
# Epoch 82/100
# 6/6 - 0s - loss: 0.0961 - val_loss: 0.0299 - 35ms/epoch - 6ms/step
# Epoch 83/100
# 6/6 - 0s - loss: 0.0995 - val_loss: 0.0294 - 33ms/epoch - 6ms/step
# Epoch 84/100
# 6/6 - 0s - loss: 0.0830 - val_loss: 0.0290 - 57ms/epoch - 9ms/step
# Epoch 85/100
# 6/6 - 0s - loss: 0.0762 - val_loss: 0.0289 - 31ms/epoch - 5ms/step
# Epoch 86/100
# 6/6 - 0s - loss: 0.0867 - val_loss: 0.0291 - 32ms/epoch - 5ms/step
# Epoch 87/100
# 6/6 - 0s - loss: 0.0790 - val_loss: 0.0291 - 31ms/epoch - 5ms/step
# Epoch 88/100
# 6/6 - 0s - loss: 0.0707 - val_loss: 0.0290 - 31ms/epoch - 5ms/step
# Epoch 89/100
# 6/6 - 0s - loss: 0.0684 - val_loss: 0.0291 - 31ms/epoch - 5ms/step
# Epoch 90/100
# 6/6 - 0s - loss: 0.0858 - val_loss: 0.0290 - 32ms/epoch - 5ms/step
# Epoch 91/100
# 6/6 - 0s - loss: 0.0776 - val_loss: 0.0290 - 32ms/epoch - 5ms/step
# Epoch 92/100
# 6/6 - 0s - loss: 0.0892 - val_loss: 0.0291 - 31ms/epoch - 5ms/step
# Epoch 93/100
# 6/6 - 0s - loss: 0.0859 - val_loss: 0.0290 - 31ms/epoch - 5ms/step
# Epoch 94/100
# 6/6 - 0s - loss: 0.0861 - val_loss: 0.0291 - 34ms/epoch - 6ms/step
# Epoch 95/100
# 6/6 - 0s - loss: 0.0742 - val_loss: 0.0291 - 34ms/epoch - 6ms/step
# Epoch 96/100
# 6/6 - 0s - loss: 0.0905 - val_loss: 0.0291 - 32ms/epoch - 5ms/step
# Epoch 97/100
# 6/6 - 0s - loss: 0.0750 - val_loss: 0.0291 - 31ms/epoch - 5ms/step
# Epoch 98/100
# 6/6 - 0s - loss: 0.0725 - val_loss: 0.0291 - 31ms/epoch - 5ms/step
# Epoch 99/100
# 6/6 - 0s - loss: 0.0812 - val_loss: 0.0291 - 31ms/epoch - 5ms/step
# Epoch 100/100
# 6/6 - 0s - loss: 0.0717 - val_loss: 0.0291 - 30ms/epoch - 5ms/step

# %%
# make a prediction
yhat = model.predict(test_X)
X = test_X.reshape((test_X.shape[0], test_X.shape[2]))

# invert scaling for prediction
dataset_yhat = concatenate((X, yhat), axis=1)
dataset_yhat = scaler.inverse_transform(dataset_yhat)
inv_yhat = dataset_yhat[:, -1]

# invert scaling for actual
y = test_y.reshape((len(test_y), 1))
dataset_y = concatenate((X, y), axis=1)
dataset_y = scaler.inverse_transform(dataset_y)
inv_y = dataset_y[:, -1]
# Out:
# 2023-12-05 03:03:42.210938: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [82,1,5]
# 	 [[{{node Placeholder/_10}}]]
# 2023-12-05 03:03:42.211160: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [82,1,5]
# 	 [[{{node Placeholder/_10}}]]
# 3/3 [==============================] - 1s 1ms/step

# %%
date = df['DATE'][train_size:]

fig, ax = plt.subplots()
fig.set_size_inches(18, 6)
ax.plot(date, inv_y / 3600, 
        linestyle='none', 
        marker='s',
        markerfacecolor='cornflowerblue', 
        markeredgecolor='black',
        markersize=7,
        label='Hours spent per day')
ax.plot(date, inv_yhat / 3600, 
        linestyle='-',
        marker='o',
        markersize=5,
        color='red',
        label='Prediction')
ax.xaxis.set_major_locator(mdates.DayLocator(interval=5))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%b-%d'))
ax.set_xlabel('Date')
ax.set_ylabel('Hours Spent')
plt.xticks(rotation=75)
ax.legend(loc='upper left')
plt.show()

# %%
# MAE
mae = mean_absolute_error(inv_y, inv_yhat) / 3600
print('MAE: %.3f' % (mae))
# Out:
# MAE: 29.315

# %%
# wo wl hr
# task type: mar
