# %%
import numpy as np
import pandas as pd
from numpy import hstack
from numpy import concatenate
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import GaussianNoise
from keras.layers import Masking
from keras import optimizers
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

import warnings
warnings.filterwarnings('ignore')

# {'DD': 0.001, 'DP2': 0.0004, 'DP1': 0.00035, 'HP1': 0.00005, 'HP2': 0.0001, 'HD': 0.0002}

# %%
df = pd.read_csv('daily_total.csv')
df['DATE'] = pd.to_datetime(df['DATE'])
df.dtypes
# Out:
# DATE            datetime64[ns]
# USERCOUNT                int64
# SECONDSSPENT             int64
# QUANTITY                 int64
# VOLUME                 float64
# WEIGHT                 float64
# PRICE                  float64
# dtype: object

# %%
df = df[df['DATE'] > '2022-08-10']
# fill missing dates with 0
df.index = df['DATE']
df = df.reindex(pd.date_range(min(df['DATE']), max(df['DATE'])), fill_value=0).drop('DATE', axis=1)
df['DATE'] = df.index
# get day of week in a new column
df['DOW'] = df['DATE'].dt.day_name()
df.drop(['DATE', 'DOW'], axis=1, inplace=True)
df
# Out:
#             USERCOUNT  SECONDSSPENT  QUANTITY       VOLUME         WEIGHT  \
# 2022-08-16         15         24864      1564     5.510447     606.628000
# 2022-08-17         46        648639    153271   900.823306   87245.837728
# 2022-08-18         72       1535976    353781  2687.981897  247269.820740
# 2022-08-19         70       1253113    395921  2944.799061  262781.058485
# 2022-08-20          6         67002       593    14.290446     975.280591
# ...               ...           ...       ...          ...            ...
# 2023-09-25        101       1171721    854092  2678.434373  292547.191456
# 2023-09-26        110       1249771   1016887  3483.392239  371822.547589
# 2023-09-27        104       1257222    939123  2998.222002  300263.198492
# 2023-09-28        109       1339688   1224169  3863.465093  384720.606181
# 2023-09-29        107       1381580   1109442  3556.001516  377380.162562
#
#                  PRICE
# 2022-08-16     7714.46
# 2022-08-17   731227.04
# 2022-08-18  2135600.74
# 2022-08-19  2136707.30
# 2022-08-20    14861.86
# ...                ...
# 2023-09-25  1875797.61
# 2023-09-26  2318629.60
# 2023-09-27  1850064.42
# 2023-09-28  2390796.27
# 2023-09-29  2196789.75
#
# [410 rows x 6 columns]

# %%
seconds_spent = df['SECONDSSPENT'].values.reshape(-1, 1)
user_count = df['USERCOUNT'].values.reshape(-1, 1)
quantity = df['QUANTITY'].values.reshape(-1, 1)
volume = df['VOLUME'].values.reshape(-1, 1)
weight = df['WEIGHT'].values.reshape(-1, 1)
price = df['PRICE'].values.reshape(-1, 1)
# dow = df['DOW'].values.reshape(-1, 1)
# year = df['DATE'].dt.year.values.reshape(-1, 1)
# month = df['DATE'].dt.month.values.reshape(-1, 1)
# day = df['DATE'].dt.day.values.reshape(-1, 1)

# # one hot encode day of week
# label_encoder = LabelEncoder()
# dow = label_encoder.fit_transform(dow)
# year = label_encoder.fit_transform(year)
# month = label_encoder.fit_transform(month)
# day = label_encoder.fit_transform(day)
# dow = dow.reshape(len(dow), 1)
# year = year.reshape(len(year), 1)
# month = month.reshape(len(month), 1)
# day = day.reshape(len(day), 1)

scaler = MinMaxScaler(feature_range=(0, 1))
# seconds_spent = scaler.fit_transform(seconds_spent)
# user_count = scaler.fit_transform(user_count)
# quantity = scaler.fit_transform(quantity)
# volume = scaler.fit_transform(volume)
# weight = scaler.fit_transform(weight)
# price = scaler.fit_transform(price)

dataset = scaler.fit_transform(hstack((quantity, volume, weight, price, seconds_spent)))

# %%
# split into train and test sets
train_size = int(len(dataset) * 0.8)
test_size = len(dataset) - train_size
train, test = dataset[:train_size, :], dataset[train_size:, :]

train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]

train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (328, 1, 4) (328,) (82, 1, 4) (82,)

# %%
# design network
np.random.seed(1234)
tf.random.set_seed(1234)

tf.keras.utils.set_random_seed(1234)
tf.config.experimental.enable_op_determinism()

optim = optimizers.Adam(lr=0.0005)
model = Sequential()
model.add(Masking(mask_value=0., input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(LSTM(16, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(1))
model.add(Dropout(0.1))
model.add(Dense(1, activation='linear'))
model.compile(loss='mae', optimizer=optim)

# fit network
history = model.fit(train_X, train_y, epochs=100, batch_size=64, validation_data=(test_X, test_y), verbose=2, shuffle=False)

# plot history
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 2023-12-05 17:50:10.049183: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [328]
# 	 [[{{node Placeholder/_11}}]]
# 2023-12-05 17:50:10.049520: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [328]
# 	 [[{{node Placeholder/_11}}]]
# 2023-12-05 17:50:12.667820: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [82]
# 	 [[{{node Placeholder/_11}}]]
# 2023-12-05 17:50:12.668079: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [82]
# 	 [[{{node Placeholder/_11}}]]
# 6/6 - 4s - loss: 0.3677 - val_loss: 0.2083 - 4s/epoch - 678ms/step
# Epoch 2/100
# 6/6 - 0s - loss: 0.3643 - val_loss: 0.2053 - 38ms/epoch - 6ms/step
# Epoch 3/100
# 6/6 - 0s - loss: 0.3604 - val_loss: 0.2023 - 35ms/epoch - 6ms/step
# Epoch 4/100
# 6/6 - 0s - loss: 0.3567 - val_loss: 0.1994 - 38ms/epoch - 6ms/step
# Epoch 5/100
# 6/6 - 0s - loss: 0.3532 - val_loss: 0.1966 - 34ms/epoch - 6ms/step
# Epoch 6/100
# 6/6 - 0s - loss: 0.3497 - val_loss: 0.1938 - 36ms/epoch - 6ms/step
# Epoch 7/100
# 6/6 - 0s - loss: 0.3461 - val_loss: 0.1910 - 36ms/epoch - 6ms/step
# Epoch 8/100
# 6/6 - 0s - loss: 0.3425 - val_loss: 0.1880 - 36ms/epoch - 6ms/step
# Epoch 9/100
# 6/6 - 0s - loss: 0.3390 - val_loss: 0.1849 - 36ms/epoch - 6ms/step
# Epoch 10/100
# 6/6 - 0s - loss: 0.3348 - val_loss: 0.1817 - 36ms/epoch - 6ms/step
# Epoch 11/100
# 6/6 - 0s - loss: 0.3310 - val_loss: 0.1784 - 35ms/epoch - 6ms/step
# Epoch 12/100
# 6/6 - 0s - loss: 0.3272 - val_loss: 0.1749 - 36ms/epoch - 6ms/step
# Epoch 13/100
# 6/6 - 0s - loss: 0.3215 - val_loss: 0.1713 - 35ms/epoch - 6ms/step
# Epoch 14/100
# 6/6 - 0s - loss: 0.3183 - val_loss: 0.1675 - 34ms/epoch - 6ms/step
# Epoch 15/100
# 6/6 - 0s - loss: 0.3132 - val_loss: 0.1635 - 37ms/epoch - 6ms/step
# Epoch 16/100
# 6/6 - 0s - loss: 0.3071 - val_loss: 0.1593 - 35ms/epoch - 6ms/step
# Epoch 17/100
# 6/6 - 0s - loss: 0.3015 - val_loss: 0.1548 - 34ms/epoch - 6ms/step
# Epoch 18/100
# 6/6 - 0s - loss: 0.2965 - val_loss: 0.1502 - 33ms/epoch - 6ms/step
# Epoch 19/100
# 6/6 - 0s - loss: 0.2937 - val_loss: 0.1455 - 32ms/epoch - 5ms/step
# Epoch 20/100
# 6/6 - 0s - loss: 0.2822 - val_loss: 0.1406 - 34ms/epoch - 6ms/step
# Epoch 21/100
# 6/6 - 0s - loss: 0.2779 - val_loss: 0.1354 - 33ms/epoch - 5ms/step
# Epoch 22/100
# 6/6 - 0s - loss: 0.2724 - val_loss: 0.1300 - 34ms/epoch - 6ms/step
# Epoch 23/100
# 6/6 - 0s - loss: 0.2636 - val_loss: 0.1245 - 35ms/epoch - 6ms/step
# Epoch 24/100
# 6/6 - 0s - loss: 0.2550 - val_loss: 0.1189 - 34ms/epoch - 6ms/step
# Epoch 25/100
# 6/6 - 0s - loss: 0.2474 - val_loss: 0.1132 - 36ms/epoch - 6ms/step
# Epoch 26/100
# 6/6 - 0s - loss: 0.2375 - val_loss: 0.1076 - 38ms/epoch - 6ms/step
# Epoch 27/100
# 6/6 - 0s - loss: 0.2309 - val_loss: 0.1020 - 39ms/epoch - 6ms/step
# Epoch 28/100
# 6/6 - 0s - loss: 0.2215 - val_loss: 0.0962 - 36ms/epoch - 6ms/step
# Epoch 29/100
# 6/6 - 0s - loss: 0.2118 - val_loss: 0.0902 - 35ms/epoch - 6ms/step
# Epoch 30/100
# 6/6 - 0s - loss: 0.1992 - val_loss: 0.0844 - 33ms/epoch - 6ms/step
# Epoch 31/100
# 6/6 - 0s - loss: 0.1868 - val_loss: 0.0792 - 35ms/epoch - 6ms/step
# Epoch 32/100
# 6/6 - 0s - loss: 0.1844 - val_loss: 0.0747 - 34ms/epoch - 6ms/step
# Epoch 33/100
# 6/6 - 0s - loss: 0.1725 - val_loss: 0.0713 - 33ms/epoch - 6ms/step
# Epoch 34/100
# 6/6 - 0s - loss: 0.1563 - val_loss: 0.0692 - 33ms/epoch - 5ms/step
# Epoch 35/100
# 6/6 - 0s - loss: 0.1557 - val_loss: 0.0680 - 32ms/epoch - 5ms/step
# Epoch 36/100
# 6/6 - 0s - loss: 0.1464 - val_loss: 0.0673 - 32ms/epoch - 5ms/step
# Epoch 37/100
# 6/6 - 0s - loss: 0.1462 - val_loss: 0.0675 - 35ms/epoch - 6ms/step
# Epoch 38/100
# 6/6 - 0s - loss: 0.1351 - val_loss: 0.0684 - 33ms/epoch - 5ms/step
# Epoch 39/100
# 6/6 - 0s - loss: 0.1423 - val_loss: 0.0695 - 35ms/epoch - 6ms/step
# Epoch 40/100
# 6/6 - 0s - loss: 0.1325 - val_loss: 0.0708 - 36ms/epoch - 6ms/step
# Epoch 41/100
# 6/6 - 0s - loss: 0.1300 - val_loss: 0.0718 - 37ms/epoch - 6ms/step
# Epoch 42/100
# 6/6 - 0s - loss: 0.1219 - val_loss: 0.0721 - 42ms/epoch - 7ms/step
# Epoch 43/100
# 6/6 - 0s - loss: 0.1346 - val_loss: 0.0718 - 35ms/epoch - 6ms/step
# Epoch 44/100
# 6/6 - 0s - loss: 0.1266 - val_loss: 0.0713 - 32ms/epoch - 5ms/step
# Epoch 45/100
# 6/6 - 0s - loss: 0.1210 - val_loss: 0.0707 - 34ms/epoch - 6ms/step
# Epoch 46/100
# 6/6 - 0s - loss: 0.1199 - val_loss: 0.0702 - 36ms/epoch - 6ms/step
# Epoch 47/100
# 6/6 - 0s - loss: 0.1286 - val_loss: 0.0695 - 33ms/epoch - 5ms/step
# Epoch 48/100
# 6/6 - 0s - loss: 0.1264 - val_loss: 0.0685 - 32ms/epoch - 5ms/step
# Epoch 49/100
# 6/6 - 0s - loss: 0.1164 - val_loss: 0.0675 - 33ms/epoch - 5ms/step
# Epoch 50/100
# 6/6 - 0s - loss: 0.1220 - val_loss: 0.0663 - 32ms/epoch - 5ms/step
# Epoch 51/100
# 6/6 - 0s - loss: 0.1253 - val_loss: 0.0648 - 34ms/epoch - 6ms/step
# Epoch 52/100
# 6/6 - 0s - loss: 0.1236 - val_loss: 0.0633 - 33ms/epoch - 6ms/step
# Epoch 53/100
# 6/6 - 0s - loss: 0.1261 - val_loss: 0.0619 - 32ms/epoch - 5ms/step
# Epoch 54/100
# 6/6 - 0s - loss: 0.1161 - val_loss: 0.0607 - 48ms/epoch - 8ms/step
# Epoch 55/100
# 6/6 - 0s - loss: 0.1060 - val_loss: 0.0597 - 35ms/epoch - 6ms/step
# Epoch 56/100
# 6/6 - 0s - loss: 0.1154 - val_loss: 0.0587 - 33ms/epoch - 6ms/step
# Epoch 57/100
# 6/6 - 0s - loss: 0.1256 - val_loss: 0.0576 - 36ms/epoch - 6ms/step
# Epoch 58/100
# 6/6 - 0s - loss: 0.1211 - val_loss: 0.0565 - 34ms/epoch - 6ms/step
# Epoch 59/100
# 6/6 - 0s - loss: 0.1098 - val_loss: 0.0555 - 33ms/epoch - 6ms/step
# Epoch 60/100
# 6/6 - 0s - loss: 0.1160 - val_loss: 0.0545 - 36ms/epoch - 6ms/step
# Epoch 61/100
# 6/6 - 0s - loss: 0.1074 - val_loss: 0.0535 - 33ms/epoch - 6ms/step
# Epoch 62/100
# 6/6 - 0s - loss: 0.1110 - val_loss: 0.0525 - 34ms/epoch - 6ms/step
# Epoch 63/100
# 6/6 - 0s - loss: 0.1267 - val_loss: 0.0516 - 34ms/epoch - 6ms/step
# Epoch 64/100
# 6/6 - 0s - loss: 0.1062 - val_loss: 0.0506 - 33ms/epoch - 6ms/step
# Epoch 65/100
# 6/6 - 0s - loss: 0.1119 - val_loss: 0.0497 - 36ms/epoch - 6ms/step
# Epoch 66/100
# 6/6 - 0s - loss: 0.1140 - val_loss: 0.0488 - 34ms/epoch - 6ms/step
# Epoch 67/100
# 6/6 - 0s - loss: 0.1055 - val_loss: 0.0480 - 32ms/epoch - 5ms/step
# Epoch 68/100
# 6/6 - 0s - loss: 0.1068 - val_loss: 0.0473 - 34ms/epoch - 6ms/step
# Epoch 69/100
# 6/6 - 0s - loss: 0.1061 - val_loss: 0.0465 - 35ms/epoch - 6ms/step
# Epoch 70/100
# 6/6 - 0s - loss: 0.1053 - val_loss: 0.0458 - 32ms/epoch - 5ms/step
# Epoch 71/100
# 6/6 - 0s - loss: 0.0980 - val_loss: 0.0450 - 33ms/epoch - 6ms/step
# Epoch 72/100
# 6/6 - 0s - loss: 0.0997 - val_loss: 0.0444 - 32ms/epoch - 5ms/step
# Epoch 73/100
# 6/6 - 0s - loss: 0.1027 - val_loss: 0.0438 - 32ms/epoch - 5ms/step
# Epoch 74/100
# 6/6 - 0s - loss: 0.1033 - val_loss: 0.0431 - 36ms/epoch - 6ms/step
# Epoch 75/100
# 6/6 - 0s - loss: 0.0980 - val_loss: 0.0425 - 34ms/epoch - 6ms/step
# Epoch 76/100
# 6/6 - 0s - loss: 0.1037 - val_loss: 0.0419 - 32ms/epoch - 5ms/step
# Epoch 77/100
# 6/6 - 0s - loss: 0.1020 - val_loss: 0.0412 - 33ms/epoch - 6ms/step
# Epoch 78/100
# 6/6 - 0s - loss: 0.0996 - val_loss: 0.0407 - 32ms/epoch - 5ms/step
# Epoch 79/100
# 6/6 - 0s - loss: 0.0931 - val_loss: 0.0401 - 32ms/epoch - 5ms/step
# Epoch 80/100
# 6/6 - 0s - loss: 0.1086 - val_loss: 0.0396 - 34ms/epoch - 6ms/step
# Epoch 81/100
# 6/6 - 0s - loss: 0.0964 - val_loss: 0.0390 - 33ms/epoch - 5ms/step
# Epoch 82/100
# 6/6 - 0s - loss: 0.1091 - val_loss: 0.0385 - 32ms/epoch - 5ms/step
# Epoch 83/100
# 6/6 - 0s - loss: 0.1125 - val_loss: 0.0380 - 36ms/epoch - 6ms/step
# Epoch 84/100
# 6/6 - 0s - loss: 0.0972 - val_loss: 0.0375 - 33ms/epoch - 5ms/step
# Epoch 85/100
# 6/6 - 0s - loss: 0.0896 - val_loss: 0.0370 - 32ms/epoch - 5ms/step
# Epoch 86/100
# 6/6 - 0s - loss: 0.0997 - val_loss: 0.0365 - 35ms/epoch - 6ms/step
# Epoch 87/100
# 6/6 - 0s - loss: 0.0914 - val_loss: 0.0360 - 33ms/epoch - 5ms/step
# Epoch 88/100
# 6/6 - 0s - loss: 0.0830 - val_loss: 0.0355 - 32ms/epoch - 5ms/step
# Epoch 89/100
# 6/6 - 0s - loss: 0.0807 - val_loss: 0.0350 - 32ms/epoch - 5ms/step
# Epoch 90/100
# 6/6 - 0s - loss: 0.0966 - val_loss: 0.0348 - 33ms/epoch - 6ms/step
# Epoch 91/100
# 6/6 - 0s - loss: 0.0878 - val_loss: 0.0345 - 32ms/epoch - 5ms/step
# Epoch 92/100
# 6/6 - 0s - loss: 0.0985 - val_loss: 0.0340 - 34ms/epoch - 6ms/step
# Epoch 93/100
# 6/6 - 0s - loss: 0.0943 - val_loss: 0.0336 - 33ms/epoch - 5ms/step
# Epoch 94/100
# 6/6 - 0s - loss: 0.0942 - val_loss: 0.0332 - 33ms/epoch - 5ms/step
# Epoch 95/100
# 6/6 - 0s - loss: 0.0822 - val_loss: 0.0328 - 34ms/epoch - 6ms/step
# Epoch 96/100
# 6/6 - 0s - loss: 0.0987 - val_loss: 0.0325 - 32ms/epoch - 5ms/step
# Epoch 97/100
# 6/6 - 0s - loss: 0.0832 - val_loss: 0.0324 - 59ms/epoch - 10ms/step
# Epoch 98/100
# 6/6 - 0s - loss: 0.0807 - val_loss: 0.0325 - 39ms/epoch - 6ms/step
# Epoch 99/100
# 6/6 - 0s - loss: 0.0895 - val_loss: 0.0327 - 33ms/epoch - 6ms/step
# Epoch 100/100
# 6/6 - 0s - loss: 0.0793 - val_loss: 0.0328 - 36ms/epoch - 6ms/step

# %%
# make a prediction
yhat = model.predict(test_X)
X = test_X.reshape((test_X.shape[0], test_X.shape[2]))

# invert scaling for prediction
dataset_yhat = concatenate((X, yhat), axis=1)
dataset_yhat = scaler.inverse_transform(dataset_yhat)
inv_yhat = dataset_yhat[:, -1]

# invert scaling for actual
y = test_y.reshape((len(test_y), 1))
dataset_y = concatenate((X, y), axis=1)
dataset_y = scaler.inverse_transform(dataset_y)
inv_y = dataset_y[:, -1]
# Out:
# 2023-12-05 17:50:17.776002: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [82,1,4]
# 	 [[{{node Placeholder/_10}}]]
# 2023-12-05 17:50:17.776295: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [82,1,4]
# 	 [[{{node Placeholder/_10}}]]
# WARNING:tensorflow:5 out of the last 34 calls to <function Model.make_predict_function.<locals>.predict_function at 0x14ffea660> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 3/3 [==============================] - 1s 1ms/step

# %%
date = df.index[train_size:]

fig, ax = plt.subplots()
fig.set_size_inches(18, 6)
ax.plot(date, inv_y / 3600, 
        linestyle='none', 
        marker='s',
        markerfacecolor='cornflowerblue', 
        markeredgecolor='black',
        markersize=7,
        label='Hours spent per day')
ax.plot(date, inv_yhat / 3600, 
        linestyle='-',
        marker='o',
        markersize=5,
        color='red',
        label='Prediction')
ax.xaxis.set_major_locator(mdates.DayLocator(interval=5))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%b-%d'))
ax.set_xlabel('Date')
ax.set_ylabel('Hours Spent')
plt.xticks(rotation=75)
ax.legend(loc='upper left')
plt.show()

# %%
# MAE
mae = mean_absolute_error(inv_y, inv_yhat) / 3600
print('MAE: %.3f' % (mae))
# Out:
# MAE: 33.076

# %%
# univariate lstm example

# %%
# wo wl hr
# task type: mar
